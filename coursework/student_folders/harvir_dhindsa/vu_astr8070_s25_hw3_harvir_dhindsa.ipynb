# %% [markdown]
# ### ASTR 3970 / 8070: Astrostatistics
# ***S. R. Taylor***
# ___
#
# # Homework 3
# ### Due: Saturday, Feb 1st at 11.59pm CST
# ---

# %% [markdown]
# ## Only one problem this week
#
# This problem uses a dataset in `/coursework/homeworks/hw_data/`.
#
# 1) Read in `hw3_data_1.npy`. This is a (100 x 2) numpy array, with measurements in the first column and uncertainties in the second column. Using the analytic results for heteroscedastic Gaussian data from lectures, compute the sample mean and the standard error on the sample mean from for this data.
#
# 2) Reusing some approaches and tools from `Lecture_6`, write a ln-likelihood function for heteroscedastic Gaussian data, and use it in a fitting algorithm to find the best-fit mean. *Remember that scipy optimizers are set up to minimize functions.*
#
# 3) Using the same numerical technique from `Lecture_5`, compute the Fisher uncertainty estimate on the mean.
#
# 4) Using the bootstrap method, generate $2000$ bootstrap realizations of this dataset. Using an appropriate timing function in python, how long did the generation of these realizations take?
# *DO NOT use the `astroML` code. Write your own bootstrap function from scratch. Also recall that when resampling data, measurements and uncertainties should stay paired together. This code will be graded on efficiency and speed; it should not take more than 1 second to execute.*
#
# 5) Repeat (2) with all $2000$ boostrap datasets to find the distribution of the sample mean. How long did this take? Plot a normalized histogram of these bootstrap means, and overplot a Gaussian pdf with the mean and std found in (1). Do these agree?
#
# 6) While we have fitted a heteroscedastic Gaussian to this data, let's try something else. Write some code to define a ln-likelihood for a Laplace distribution evaluated on this data. Fit simultaneously for the Laplace location parameter $\mu$ and scale parameter $\Delta$.
#
# 7) Compute the AIC values for the heteroscedastic Gaussian model and the Laplacian model. Which model is favored by the data?
#
# 8) Using the $2000$ bootstrap datasets from before, fit for the Laplacian $\mu$ and $\Delta$ for each. Make a nice `corner` plot of the distributions of $\mu$ and $\Delta$ that shows both the marginal $1$D distributions and the joint $2$D distribution. Make sure the plot has labels, shows the titles on each $1$D marginal panel, and has $68\%$ and $95\%$ levels.
#
# 9) Let's finish with a Fisher uncertainty estimate of the Laplacian parameters. Use the following code to install `numdifftools` which provides a simple way to compute derivatives. We can then compute the Hessian matrix, which is the matrix of the second derivatives of the user's function. This should be computed at the best-fit Laplacian parameters $\mu$ and $\Delta$. To finish, invert the matrix, and then take the square root. The diagonal entries will then be the Fisher uncertainties on $\mu$ and $\Delta$. How does these compare to the bootstrap distribution widths found in (8)?

# %% [markdown]
# I had a packed weekend when this homework was due, and even Monday was busy; I should have planned an extension earlier in the week. I am submitting what I can, and I've got to plan for the future homeworks properly.

# %%
# !pip install numdifftools

# %%
import numdifftools as nd
H = nd.Hessian(f_lnlaplace)([beta_laplace[0], beta_laplace[1]])
sigma_laplace = np.linalg.inv(H)**0.5

# %% [markdown]
# ### Solution

# %%
import numpy as np

#PROBLEM 1

filename = "/Users/harvir_d/NEW_repos/astr_8070_s25/coursework/homeworks/hw_data/hw3_data_1.npy" # file path
data = np.load(filename) # easy to load multivariate data if from a numpy file

measurements = data[:,0] # extracting column at a time
uncertainties = data[:,1]

numerator = np.sum(measurements / (uncertainties**2)) # we can apply element wise operations row by row in our data
denominator = np.sum(1 / (uncertainties**2))

sample_mean = numerator / denominator

sample_error_mean = (np.sum(1 / (uncertainties**2)))**(-0.5)

print("The sample mean computed analytically is: %.4f" % sample_mean)
print("The sample error of the mean computed analytically is: %.4f" % sample_error_mean)
# Out:
# The sample mean computed analytically is: 4.0821
# The sample error of the mean computed analytically is: 0.0938

# %%
#PROBLEM 2

from scipy import optimize
from scipy.stats import norm

# We can compare two extracted mean values for our data to the sample mean from (1). 

# The first method is defining a squared loss function like with the Chi_squared in class, except now that we have a heteroscedastic Gaussian, we will not be fitting to a line but rather each individual data point (measurement, uncertainty) to a "best guess mean" beta
# the line of best fit method does not make sense here because the Gaussian does not have a constant variance, and instead each data point has an associated error bar

def squared_loss(y, y_fit, dy):
    # minimizing the sum of the residuals will result in our best-fit mean
    return np.sum(((y - y_fit) / dy) ** 2, -1) # -1 is a sum over a specific axis for the 1D array in question (for multi-dimensional arrays, we could specify an axis to sum over)

f_squared = lambda beta: squared_loss(data[:,0], beta, data[:,1]) # lambda is an option that allows us to pre-load guesses into our callable function so we do not have to change the function or function call itself when we want to adjust our initial guess beta
beta = 4 # guess for fitting algorithm to start with

# adjusting our initial guess for the mean by iteratively going thorugh selections of beta, until the residual sum is minimized
best_fit_mean = optimize.fmin(f_squared,beta)
print("The mean from our fitting algorithm is: %.4f" % best_fit_mean)



# the second method for extracting the mean of our data is by directly maximizing the Likelihood function

xgrid = np.linspace(3,5,1000) # array space for possible mean values
L_single = np.ones((data.shape[0],1000)) # allocating array space for individual measurement likelihoods
for i in range(len(data)): # continuing loop through each paired data point
    L_single[i] = norm.pdf(xgrid,loc=data[i,0],scale=data[i,1]) # inidividual measurement likelihoods stored

L = np.prod(L_single,axis=0) # Likelihood for dataset as a whole

sorted_indices = np.argsort(L)[-1] # argsort rearranges array in ascending order, [-1] chooses the last value in array and that is the maximum likelihood value
print("The MLE for the mean is: %.4f" % xgrid[sorted_indices])
# Out:
# Optimization terminated successfully.
#          Current function value: 126.238875
#          Iterations: 12
#          Function evaluations: 24
# The mean from our fitting algorithm is: 4.0821
# The MLE for the mean is: 4.0831
# /var/folders/5y/r0thn5qs437_z1rk3srjhx3r0000gn/T/ipykernel_1127/4081519588.py:20: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("The mean from our fitting algorithm is: %.4f" % best_fit_mean)

# %%
#PROBLEM 3

sigma_mu = np.diff(np.log(L), n=2) # 2nd order differentiation of lnL
sigma_mu /= (xgrid[1]-xgrid[0])**2 # numerial differentiation with respect to the grid size per step
sigma_mu *= -1 # part of Fisher calculation
sigma_mu = 1/np.sqrt(sigma_mu)[0] 

print("Fisher matrix error on estimated mean is %.4f" % sigma_mu)
# Out:
# Fisher matrix error on estimated mean is 0.0938

# %%
#PROBLEM 4

import time

num_bootstrap = 2000 # number of bootstrap resamplings we want

num_old_rows = data.shape[0] # 100, number of paired values in original dataset
num_new_rows = 100 # number of paired values we want to extract from the original dataset (in a random way) for each of the 2000 resamplings

bootstrap_resamplings = np.empty((num_bootstrap, num_new_rows, data.shape[1])) # pre-allocating 3D array for our complete bootstrap data set, 2000 partitioned resamples that are num_new_rows x 2 in dimension

total_start_time = time.perf_counter() # start time for running entire loop for bootstrap

for i in range(num_bootstrap):
    loop_time_start = time.perf_counter() # time start for this loop iteration

    # sampling with replacement for bootstrapping
    indices = np.random.choice(data.shape[0], size=num_new_rows, replace=True) # randomly selecting rows from original dataset, results in a list of numbers where each number is a row from *data*

    bootstrap_resamplings[i] = data[indices] # the ith partition of our 3D array of bootstrapping contains the randomly selected rows or paired values from the original dataset

    loop_time_end = time.perf_counter()

    print(f"Loop {i+1:4d}/{num_bootstrap} took: {loop_time_end - loop_time_start:.6f} seconds")

total_end_time = time.perf_counter()

print(f"Total time for {num_bootstrap} loops: {total_end_time - total_start_time:.6f} seconds")
# Out:
# Loop    1/2000 took: 0.087945 seconds
# Loop    2/2000 took: 0.000043 seconds
# Loop    3/2000 took: 0.000027 seconds
# Loop    4/2000 took: 0.000036 seconds
# Loop    5/2000 took: 0.000020 seconds
# Loop    6/2000 took: 0.000015 seconds
# Loop    7/2000 took: 0.000029 seconds
# Loop    8/2000 took: 0.000027 seconds
# Loop    9/2000 took: 0.000017 seconds
# Loop   10/2000 took: 0.000016 seconds
# Loop   11/2000 took: 0.000019 seconds
# Loop   12/2000 took: 0.000015 seconds
# Loop   13/2000 took: 0.000013 seconds
# Loop   14/2000 took: 0.000013 seconds
# Loop   15/2000 took: 0.000013 seconds
# Loop   16/2000 took: 0.000019 seconds
# Loop   17/2000 took: 0.000149 seconds
# Loop   18/2000 took: 0.000012 seconds
# Loop   19/2000 took: 0.000011 seconds
# Loop   20/2000 took: 0.000011 seconds
# Loop   21/2000 took: 0.000012 seconds
# Loop   22/2000 took: 0.000011 seconds
# Loop   23/2000 took: 0.000010 seconds
# Loop   24/2000 took: 0.000010 seconds
# Loop   25/2000 took: 0.000010 seconds
# Loop   26/2000 took: 0.000010 seconds
# Loop   27/2000 took: 0.000011 seconds
# Loop   28/2000 took: 0.000010 seconds
# Loop   29/2000 took: 0.000010 seconds
# Loop   30/2000 took: 0.000010 seconds
# Loop   31/2000 took: 0.000014 seconds
# Loop   32/2000 took: 0.000010 seconds
# Loop   33/2000 took: 0.000010 seconds
# Loop   34/2000 took: 0.000010 seconds
# Loop   35/2000 took: 0.000010 seconds
# Loop   36/2000 took: 0.000010 seconds
# Loop   37/2000 took: 0.000010 seconds
# Loop   38/2000 took: 0.000010 seconds
# Loop   39/2000 took: 0.000010 seconds
# Loop   40/2000 took: 0.000010 seconds
# Loop   41/2000 took: 0.000012 seconds
# Loop   42/2000 took: 0.000010 seconds
# Loop   43/2000 took: 0.000010 seconds
# Loop   44/2000 took: 0.000010 seconds
# Loop   45/2000 took: 0.000011 seconds
# Loop   46/2000 took: 0.000010 seconds
# Loop   47/2000 took: 0.000010 seconds
# Loop   48/2000 took: 0.000010 seconds
# Loop   49/2000 took: 0.000010 seconds
# Loop   50/2000 took: 0.000010 seconds
# Loop   51/2000 took: 0.000010 seconds
# Loop   52/2000 took: 0.000014 seconds
# Loop   53/2000 took: 0.000017 seconds
# Loop   54/2000 took: 0.000010 seconds
# Loop   55/2000 took: 0.000010 seconds
# Loop   56/2000 took: 0.000010 seconds
# Loop   57/2000 took: 0.000010 seconds
# Loop   58/2000 took: 0.000010 seconds
# Loop   59/2000 took: 0.000010 seconds
# Loop   60/2000 took: 0.000010 seconds
# Loop   61/2000 took: 0.000010 seconds
# Loop   62/2000 took: 0.000014 seconds
# Loop   63/2000 took: 0.000010 seconds
# Loop   64/2000 took: 0.000010 seconds
# Loop   65/2000 took: 0.000010 seconds
# Loop   66/2000 took: 0.000010 seconds
# Loop   67/2000 took: 0.000010 seconds
# Loop   68/2000 took: 0.000010 seconds
# Loop   69/2000 took: 0.000010 seconds
# Loop   70/2000 took: 0.000010 seconds
# Loop   71/2000 took: 0.000010 seconds
# Loop   72/2000 took: 0.000011 seconds
# Loop   73/2000 took: 0.000010 seconds
# Loop   74/2000 took: 0.000010 seconds
# Loop   75/2000 took: 0.000010 seconds
# Loop   76/2000 took: 0.000010 seconds
# Loop   77/2000 took: 0.000010 seconds
# Loop   78/2000 took: 0.000010 seconds
# Loop   79/2000 took: 0.000010 seconds
# Loop   80/2000 took: 0.000010 seconds
# Loop   81/2000 took: 0.000009 seconds
# Loop   82/2000 took: 0.000011 seconds
# Loop   83/2000 took: 0.000010 seconds
# Loop   84/2000 took: 0.000010 seconds
# Loop   85/2000 took: 0.000010 seconds
# Loop   86/2000 took: 0.000009 seconds
# Loop   87/2000 took: 0.000010 seconds
# Loop   88/2000 took: 0.000010 seconds
# Loop   89/2000 took: 0.000010 seconds
# Loop   90/2000 took: 0.000010 seconds
# Loop   91/2000 took: 0.000010 seconds
# Loop   92/2000 took: 0.000010 seconds
# Loop   93/2000 took: 0.000012 seconds
# Loop   94/2000 took: 0.000010 seconds
# Loop   95/2000 took: 0.000009 seconds
# Loop   96/2000 took: 0.000010 seconds
# Loop   97/2000 took: 0.000010 seconds
# Loop   98/2000 took: 0.000010 seconds
# Loop   99/2000 took: 0.000010 seconds
# Loop  100/2000 took: 0.000010 seconds
# Loop  101/2000 took: 0.000010 seconds
# Loop  102/2000 took: 0.000010 seconds
# Loop  103/2000 took: 0.000012 seconds
# Loop  104/2000 took: 0.000010 seconds
# Loop  105/2000 took: 0.000010 seconds
# Loop  106/2000 took: 0.000010 seconds
# Loop  107/2000 took: 0.000010 seconds
# Loop  108/2000 took: 0.000010 seconds
# Loop  109/2000 took: 0.000009 seconds
# Loop  110/2000 took: 0.000010 seconds
# Loop  111/2000 took: 0.000010 seconds
# Loop  112/2000 took: 0.000010 seconds
# Loop  113/2000 took: 0.000011 seconds
# Loop  114/2000 took: 0.000010 seconds
# Loop  115/2000 took: 0.000010 seconds
# Loop  116/2000 took: 0.000010 seconds
# Loop  117/2000 took: 0.000010 seconds
# Loop  118/2000 took: 0.000010 seconds
# Loop  119/2000 took: 0.000010 seconds
# Loop  120/2000 took: 0.000010 seconds
# Loop  121/2000 took: 0.000010 seconds
# Loop  122/2000 took: 0.000009 seconds
# Loop  123/2000 took: 0.000011 seconds
# Loop  124/2000 took: 0.000010 seconds
# Loop  125/2000 took: 0.000010 seconds
# Loop  126/2000 took: 0.000010 seconds
# Loop  127/2000 took: 0.000010 seconds
# Loop  128/2000 took: 0.000010 seconds
# Loop  129/2000 took: 0.000009 seconds
# Loop  130/2000 took: 0.000010 seconds
# Loop  131/2000 took: 0.000010 seconds
# Loop  132/2000 took: 0.000010 seconds
# Loop  133/2000 took: 0.000010 seconds
# Loop  134/2000 took: 0.000011 seconds
# Loop  135/2000 took: 0.000010 seconds
# Loop  136/2000 took: 0.000010 seconds
# Loop  137/2000 took: 0.000010 seconds
# Loop  138/2000 took: 0.000010 seconds
# Loop  139/2000 took: 0.000009 seconds
# Loop  140/2000 took: 0.000010 seconds
# Loop  141/2000 took: 0.000010 seconds
# Loop  142/2000 took: 0.000010 seconds
# Loop  143/2000 took: 0.000010 seconds
# Loop  144/2000 took: 0.000014 seconds
# Loop  145/2000 took: 0.000010 seconds
# Loop  146/2000 took: 0.000010 seconds
# Loop  147/2000 took: 0.000010 seconds
# Loop  148/2000 took: 0.000010 seconds
# Loop  149/2000 took: 0.000010 seconds
# Loop  150/2000 took: 0.000010 seconds
# Loop  151/2000 took: 0.000010 seconds
# Loop  152/2000 took: 0.000010 seconds
# Loop  153/2000 took: 0.000010 seconds
# Loop  154/2000 took: 0.000012 seconds
# Loop  155/2000 took: 0.000010 seconds
# Loop  156/2000 took: 0.000010 seconds
# Loop  157/2000 took: 0.000010 seconds
# Loop  158/2000 took: 0.000010 seconds
# Loop  159/2000 took: 0.000010 seconds
# Loop  160/2000 took: 0.000009 seconds
# Loop  161/2000 took: 0.000010 seconds
# Loop  162/2000 took: 0.000010 seconds
# Loop  163/2000 took: 0.000010 seconds
# Loop  164/2000 took: 0.000012 seconds
# Loop  165/2000 took: 0.000010 seconds
# Loop  166/2000 took: 0.000010 seconds
# Loop  167/2000 took: 0.000010 seconds
# Loop  168/2000 took: 0.000010 seconds
# Loop  169/2000 took: 0.000010 seconds
# Loop  170/2000 took: 0.000010 seconds
# Loop  171/2000 took: 0.000010 seconds
# Loop  172/2000 took: 0.000010 seconds
# Loop  173/2000 took: 0.000009 seconds
# Loop  174/2000 took: 0.000010 seconds
# Loop  175/2000 took: 0.000011 seconds
# Loop  176/2000 took: 0.000010 seconds
# Loop  177/2000 took: 0.000010 seconds
# Loop  178/2000 took: 0.000010 seconds
# Loop  179/2000 took: 0.000010 seconds
# Loop  180/2000 took: 0.000010 seconds
# Loop  181/2000 took: 0.000010 seconds
# Loop  182/2000 took: 0.000010 seconds
# Loop  183/2000 took: 0.000010 seconds
# Loop  184/2000 took: 0.000010 seconds
# Loop  185/2000 took: 0.000011 seconds
# Loop  186/2000 took: 0.000010 seconds
# Loop  187/2000 took: 0.000010 seconds
# Loop  188/2000 took: 0.000010 seconds
# Loop  189/2000 took: 0.000010 seconds
# Loop  190/2000 took: 0.000010 seconds
# Loop  191/2000 took: 0.000010 seconds
# Loop  192/2000 took: 0.000010 seconds
# Loop  193/2000 took: 0.000010 seconds
# Loop  194/2000 took: 0.000009 seconds
# Loop  195/2000 took: 0.000011 seconds
# Loop  196/2000 took: 0.000010 seconds
# Loop  197/2000 took: 0.000010 seconds
# Loop  198/2000 took: 0.000010 seconds
# Loop  199/2000 took: 0.000010 seconds
# Loop  200/2000 took: 0.000010 seconds
# Loop  201/2000 took: 0.000010 seconds
# Loop  202/2000 took: 0.000010 seconds
# Loop  203/2000 took: 0.000010 seconds
# Loop  204/2000 took: 0.000010 seconds
# Loop  205/2000 took: 0.000011 seconds
# Loop  206/2000 took: 0.000010 seconds
# Loop  207/2000 took: 0.000010 seconds
# Loop  208/2000 took: 0.000010 seconds
# Loop  209/2000 took: 0.000010 seconds
# Loop  210/2000 took: 0.000010 seconds
# Loop  211/2000 took: 0.000010 seconds
# Loop  212/2000 took: 0.000010 seconds
# Loop  213/2000 took: 0.000010 seconds
# Loop  214/2000 took: 0.000010 seconds
# Loop  215/2000 took: 0.000010 seconds
# Loop  216/2000 took: 0.000011 seconds
# Loop  217/2000 took: 0.000010 seconds
# Loop  218/2000 took: 0.000010 seconds
# Loop  219/2000 took: 0.000010 seconds
# Loop  220/2000 took: 0.000010 seconds
# Loop  221/2000 took: 0.000010 seconds
# Loop  222/2000 took: 0.000010 seconds
# Loop  223/2000 took: 0.000010 seconds
# Loop  224/2000 took: 0.000010 seconds
# Loop  225/2000 took: 0.000010 seconds
# Loop  226/2000 took: 0.000011 seconds
# Loop  227/2000 took: 0.000010 seconds
# Loop  228/2000 took: 0.000010 seconds
# Loop  229/2000 took: 0.000010 seconds
# Loop  230/2000 took: 0.000010 seconds
# Loop  231/2000 took: 0.000009 seconds
# Loop  232/2000 took: 0.000010 seconds
# Loop  233/2000 took: 0.000010 seconds
# Loop  234/2000 took: 0.000010 seconds
# Loop  235/2000 took: 0.000010 seconds
# Loop  236/2000 took: 0.000011 seconds
# Loop  237/2000 took: 0.000010 seconds
# Loop  238/2000 took: 0.000010 seconds
# Loop  239/2000 took: 0.000010 seconds
# Loop  240/2000 took: 0.000009 seconds
# Loop  241/2000 took: 0.000010 seconds
# Loop  242/2000 took: 0.000010 seconds
# Loop  243/2000 took: 0.000010 seconds
# Loop  244/2000 took: 0.000010 seconds
# Loop  245/2000 took: 0.000009 seconds
# Loop  246/2000 took: 0.000011 seconds
# Loop  247/2000 took: 0.000010 seconds
# Loop  248/2000 took: 0.000010 seconds
# Loop  249/2000 took: 0.000010 seconds
# Loop  250/2000 took: 0.000010 seconds
# Loop  251/2000 took: 0.000010 seconds
# Loop  252/2000 took: 0.000010 seconds
# Loop  253/2000 took: 0.000010 seconds
# Loop  254/2000 took: 0.000010 seconds
# Loop  255/2000 took: 0.000010 seconds
# Loop  256/2000 took: 0.000010 seconds
# Loop  257/2000 took: 0.000011 seconds
# Loop  258/2000 took: 0.000010 seconds
# Loop  259/2000 took: 0.000010 seconds
# Loop  260/2000 took: 0.000010 seconds
# Loop  261/2000 took: 0.000010 seconds
# Loop  262/2000 took: 0.000010 seconds
# Loop  263/2000 took: 0.000010 seconds
# Loop  264/2000 took: 0.000010 seconds
# Loop  265/2000 took: 0.000009 seconds
# Loop  266/2000 took: 0.000010 seconds
# Loop  267/2000 took: 0.000012 seconds
# Loop  268/2000 took: 0.000010 seconds
# Loop  269/2000 took: 0.000010 seconds
# Loop  270/2000 took: 0.000010 seconds
# Loop  271/2000 took: 0.000009 seconds
# Loop  272/2000 took: 0.000010 seconds
# Loop  273/2000 took: 0.000010 seconds
# Loop  274/2000 took: 0.000010 seconds
# Loop  275/2000 took: 0.000009 seconds
# Loop  276/2000 took: 0.000010 seconds
# Loop  277/2000 took: 0.000012 seconds
# Loop  278/2000 took: 0.000010 seconds
# Loop  279/2000 took: 0.000010 seconds
# Loop  280/2000 took: 0.000010 seconds
# Loop  281/2000 took: 0.000010 seconds
# Loop  282/2000 took: 0.000010 seconds
# Loop  283/2000 took: 0.000010 seconds
# Loop  284/2000 took: 0.000010 seconds
# Loop  285/2000 took: 0.000010 seconds
# Loop  286/2000 took: 0.000010 seconds
# Loop  287/2000 took: 0.000011 seconds
# Loop  288/2000 took: 0.000010 seconds
# Loop  289/2000 took: 0.000010 seconds
# Loop  290/2000 took: 0.000010 seconds
# Loop  291/2000 took: 0.000010 seconds
# Loop  292/2000 took: 0.000010 seconds
# Loop  293/2000 took: 0.000010 seconds
# Loop  294/2000 took: 0.000010 seconds
# Loop  295/2000 took: 0.000010 seconds
# Loop  296/2000 took: 0.000010 seconds
# Loop  297/2000 took: 0.000011 seconds
# Loop  298/2000 took: 0.000010 seconds
# Loop  299/2000 took: 0.000010 seconds
# Loop  300/2000 took: 0.000010 seconds
# Loop  301/2000 took: 0.000010 seconds
# Loop  302/2000 took: 0.000010 seconds
# Loop  303/2000 took: 0.000010 seconds
# Loop  304/2000 took: 0.000010 seconds
# Loop  305/2000 took: 0.000009 seconds
# Loop  306/2000 took: 0.000009 seconds
# Loop  307/2000 took: 0.000009 seconds
# Loop  308/2000 took: 0.000014 seconds
# Loop  309/2000 took: 0.000010 seconds
# Loop  310/2000 took: 0.000010 seconds
# Loop  311/2000 took: 0.000010 seconds
# Loop  312/2000 took: 0.000010 seconds
# Loop  313/2000 took: 0.000010 seconds
# Loop  314/2000 took: 0.000010 seconds
# Loop  315/2000 took: 0.000010 seconds
# Loop  316/2000 took: 0.000010 seconds
# Loop  317/2000 took: 0.000010 seconds
# Loop  318/2000 took: 0.000011 seconds
# Loop  319/2000 took: 0.000010 seconds
# Loop  320/2000 took: 0.000009 seconds
# Loop  321/2000 took: 0.000009 seconds
# Loop  322/2000 took: 0.000010 seconds
# Loop  323/2000 took: 0.000010 seconds
# Loop  324/2000 took: 0.000010 seconds
# Loop  325/2000 took: 0.000010 seconds
# Loop  326/2000 took: 0.000010 seconds
# Loop  327/2000 took: 0.000010 seconds
# Loop  328/2000 took: 0.000011 seconds
# Loop  329/2000 took: 0.000010 seconds
# Loop  330/2000 took: 0.000010 seconds
# Loop  331/2000 took: 0.000010 seconds
# Loop  332/2000 took: 0.000010 seconds
# Loop  333/2000 took: 0.000010 seconds
# Loop  334/2000 took: 0.000010 seconds
# Loop  335/2000 took: 0.000010 seconds
# Loop  336/2000 took: 0.000010 seconds
# Loop  337/2000 took: 0.000010 seconds
# Loop  338/2000 took: 0.000011 seconds
# Loop  339/2000 took: 0.000010 seconds
# Loop  340/2000 took: 0.000010 seconds
# Loop  341/2000 took: 0.000010 seconds
# Loop  342/2000 took: 0.000010 seconds
# Loop  343/2000 took: 0.000010 seconds
# Loop  344/2000 took: 0.000010 seconds
# Loop  345/2000 took: 0.000010 seconds
# Loop  346/2000 took: 0.000010 seconds
# Loop  347/2000 took: 0.000010 seconds
# Loop  348/2000 took: 0.000010 seconds
# Loop  349/2000 took: 0.000013 seconds
# Loop  350/2000 took: 0.000010 seconds
# Loop  351/2000 took: 0.000010 seconds
# Loop  352/2000 took: 0.000010 seconds
# Loop  353/2000 took: 0.000010 seconds
# Loop  354/2000 took: 0.000010 seconds
# Loop  355/2000 took: 0.000010 seconds
# Loop  356/2000 took: 0.000010 seconds
# Loop  357/2000 took: 0.000010 seconds
# Loop  358/2000 took: 0.000010 seconds
# Loop  359/2000 took: 0.000011 seconds
# Loop  360/2000 took: 0.000010 seconds
# Loop  361/2000 took: 0.000010 seconds
# Loop  362/2000 took: 0.000010 seconds
# Loop  363/2000 took: 0.000010 seconds
# Loop  364/2000 took: 0.000010 seconds
# Loop  365/2000 took: 0.000009 seconds
# Loop  366/2000 took: 0.000010 seconds
# Loop  367/2000 took: 0.000010 seconds
# Loop  368/2000 took: 0.000010 seconds
# Loop  369/2000 took: 0.000011 seconds
# Loop  370/2000 took: 0.000010 seconds
# Loop  371/2000 took: 0.000010 seconds
# Loop  372/2000 took: 0.000010 seconds
# Loop  373/2000 took: 0.000009 seconds
# Loop  374/2000 took: 0.000009 seconds
# Loop  375/2000 took: 0.000009 seconds
# Loop  376/2000 took: 0.000010 seconds
# Loop  377/2000 took: 0.000010 seconds
# Loop  378/2000 took: 0.000010 seconds
# Loop  379/2000 took: 0.000011 seconds
# Loop  380/2000 took: 0.000010 seconds
# Loop  381/2000 took: 0.000010 seconds
# Loop  382/2000 took: 0.000010 seconds
# Loop  383/2000 took: 0.000010 seconds
# Loop  384/2000 took: 0.000010 seconds
# Loop  385/2000 took: 0.000010 seconds
# Loop  386/2000 took: 0.000010 seconds
# Loop  387/2000 took: 0.000010 seconds
# Loop  388/2000 took: 0.000010 seconds
# Loop  389/2000 took: 0.000010 seconds
# Loop  390/2000 took: 0.000011 seconds
# Loop  391/2000 took: 0.000010 seconds
# Loop  392/2000 took: 0.000010 seconds
# Loop  393/2000 took: 0.000010 seconds
# Loop  394/2000 took: 0.000010 seconds
# Loop  395/2000 took: 0.000010 seconds
# Loop  396/2000 took: 0.000010 seconds
# Loop  397/2000 took: 0.000010 seconds
# Loop  398/2000 took: 0.000009 seconds
# Loop  399/2000 took: 0.000009 seconds
# Loop  400/2000 took: 0.000011 seconds
# Loop  401/2000 took: 0.000010 seconds
# Loop  402/2000 took: 0.000010 seconds
# Loop  403/2000 took: 0.000010 seconds
# Loop  404/2000 took: 0.000010 seconds
# Loop  405/2000 took: 0.000010 seconds
# Loop  406/2000 took: 0.000010 seconds
# Loop  407/2000 took: 0.000010 seconds
# Loop  408/2000 took: 0.000010 seconds
# Loop  409/2000 took: 0.000010 seconds
# Loop  410/2000 took: 0.000011 seconds
# Loop  411/2000 took: 0.000010 seconds
# Loop  412/2000 took: 0.000010 seconds
# Loop  413/2000 took: 0.000009 seconds
# Loop  414/2000 took: 0.000010 seconds
# Loop  415/2000 took: 0.000010 seconds
# Loop  416/2000 took: 0.000010 seconds
# Loop  417/2000 took: 0.000009 seconds
# Loop  418/2000 took: 0.000010 seconds
# Loop  419/2000 took: 0.000010 seconds
# Loop  420/2000 took: 0.000011 seconds
# Loop  421/2000 took: 0.000010 seconds
# Loop  422/2000 took: 0.000010 seconds
# Loop  423/2000 took: 0.000013 seconds
# Loop  424/2000 took: 0.000010 seconds
# Loop  425/2000 took: 0.000010 seconds
# Loop  426/2000 took: 0.000010 seconds
# Loop  427/2000 took: 0.000010 seconds
# Loop  428/2000 took: 0.000009 seconds
# Loop  429/2000 took: 0.000010 seconds
# Loop  430/2000 took: 0.000010 seconds
# Loop  431/2000 took: 0.000011 seconds
# Loop  432/2000 took: 0.000010 seconds
# Loop  433/2000 took: 0.000010 seconds
# Loop  434/2000 took: 0.000010 seconds
# Loop  435/2000 took: 0.000010 seconds
# Loop  436/2000 took: 0.000010 seconds
# Loop  437/2000 took: 0.000010 seconds
# Loop  438/2000 took: 0.000010 seconds
# Loop  439/2000 took: 0.000010 seconds
# Loop  440/2000 took: 0.000009 seconds
# Loop  441/2000 took: 0.000011 seconds
# Loop  442/2000 took: 0.000010 seconds
# Loop  443/2000 took: 0.000010 seconds
# Loop  444/2000 took: 0.000010 seconds
# Loop  445/2000 took: 0.000009 seconds
# Loop  446/2000 took: 0.000010 seconds
# Loop  447/2000 took: 0.000010 seconds
# Loop  448/2000 took: 0.000010 seconds
# Loop  449/2000 took: 0.000010 seconds
# Loop  450/2000 took: 0.000010 seconds
# Loop  451/2000 took: 0.000011 seconds
# Loop  452/2000 took: 0.000010 seconds
# Loop  453/2000 took: 0.000010 seconds
# Loop  454/2000 took: 0.000010 seconds
# Loop  455/2000 took: 0.000010 seconds
# Loop  456/2000 took: 0.000010 seconds
# Loop  457/2000 took: 0.000010 seconds
# Loop  458/2000 took: 0.000010 seconds
# Loop  459/2000 took: 0.000010 seconds
# Loop  460/2000 took: 0.000010 seconds
# Loop  461/2000 took: 0.000011 seconds
# Loop  462/2000 took: 0.000010 seconds
# Loop  463/2000 took: 0.000010 seconds
# Loop  464/2000 took: 0.000010 seconds
# Loop  465/2000 took: 0.000009 seconds
# Loop  466/2000 took: 0.000010 seconds
# Loop  467/2000 took: 0.000009 seconds
# Loop  468/2000 took: 0.000010 seconds
# Loop  469/2000 took: 0.000010 seconds
# Loop  470/2000 took: 0.000010 seconds
# Loop  471/2000 took: 0.000009 seconds
# Loop  472/2000 took: 0.000011 seconds
# Loop  473/2000 took: 0.000010 seconds
# Loop  474/2000 took: 0.000009 seconds
# Loop  475/2000 took: 0.000009 seconds
# Loop  476/2000 took: 0.000010 seconds
# Loop  477/2000 took: 0.000010 seconds
# Loop  478/2000 took: 0.000010 seconds
# Loop  479/2000 took: 0.000010 seconds
# Loop  480/2000 took: 0.000010 seconds
# Loop  481/2000 took: 0.000010 seconds
# Loop  482/2000 took: 0.000011 seconds
# Loop  483/2000 took: 0.000010 seconds
# Loop  484/2000 took: 0.000010 seconds
# Loop  485/2000 took: 0.000009 seconds
# Loop  486/2000 took: 0.000010 seconds
# Loop  487/2000 took: 0.000010 seconds
# Loop  488/2000 took: 0.000010 seconds
# Loop  489/2000 took: 0.000009 seconds
# Loop  490/2000 took: 0.000010 seconds
# Loop  491/2000 took: 0.000010 seconds
# Loop  492/2000 took: 0.000011 seconds
# Loop  493/2000 took: 0.000010 seconds
# Loop  494/2000 took: 0.000010 seconds
# Loop  495/2000 took: 0.000010 seconds
# Loop  496/2000 took: 0.000010 seconds
# Loop  497/2000 took: 0.000009 seconds
# Loop  498/2000 took: 0.000010 seconds
# Loop  499/2000 took: 0.000010 seconds
# Loop  500/2000 took: 0.000010 seconds
# Loop  501/2000 took: 0.000010 seconds
# Loop  502/2000 took: 0.000011 seconds
# Loop  503/2000 took: 0.000010 seconds
# Loop  504/2000 took: 0.000010 seconds
# Loop  505/2000 took: 0.000010 seconds
# Loop  506/2000 took: 0.000010 seconds
# Loop  507/2000 took: 0.000010 seconds
# Loop  508/2000 took: 0.000010 seconds
# Loop  509/2000 took: 0.000010 seconds
# Loop  510/2000 took: 0.000010 seconds
# Loop  511/2000 took: 0.000010 seconds
# Loop  512/2000 took: 0.000010 seconds
# Loop  513/2000 took: 0.000011 seconds
# Loop  514/2000 took: 0.000010 seconds
# Loop  515/2000 took: 0.000010 seconds
# Loop  516/2000 took: 0.000010 seconds
# Loop  517/2000 took: 0.000010 seconds
# Loop  518/2000 took: 0.000010 seconds
# Loop  519/2000 took: 0.000010 seconds
# Loop  520/2000 took: 0.000010 seconds
# Loop  521/2000 took: 0.000010 seconds
# Loop  522/2000 took: 0.000010 seconds
# Loop  523/2000 took: 0.000011 seconds
# Loop  524/2000 took: 0.000010 seconds
# Loop  525/2000 took: 0.000010 seconds
# Loop  526/2000 took: 0.000010 seconds
# Loop  527/2000 took: 0.000010 seconds
# Loop  528/2000 took: 0.000009 seconds
# Loop  529/2000 took: 0.000009 seconds
# Loop  530/2000 took: 0.000010 seconds
# Loop  531/2000 took: 0.000010 seconds
# Loop  532/2000 took: 0.000010 seconds
# Loop  533/2000 took: 0.000011 seconds
# Loop  534/2000 took: 0.000010 seconds
# Loop  535/2000 took: 0.000010 seconds
# Loop  536/2000 took: 0.000010 seconds
# Loop  537/2000 took: 0.000010 seconds
# Loop  538/2000 took: 0.000010 seconds
# Loop  539/2000 took: 0.000010 seconds
# Loop  540/2000 took: 0.000010 seconds
# Loop  541/2000 took: 0.000010 seconds
# Loop  542/2000 took: 0.000010 seconds
# Loop  543/2000 took: 0.000011 seconds
# Loop  544/2000 took: 0.000010 seconds
# Loop  545/2000 took: 0.000010 seconds
# Loop  546/2000 took: 0.000010 seconds
# Loop  547/2000 took: 0.000010 seconds
# Loop  548/2000 took: 0.000010 seconds
# Loop  549/2000 took: 0.000009 seconds
# Loop  550/2000 took: 0.000010 seconds
# Loop  551/2000 took: 0.000010 seconds
# Loop  552/2000 took: 0.000010 seconds
# Loop  553/2000 took: 0.000011 seconds
# Loop  554/2000 took: 0.000010 seconds
# Loop  555/2000 took: 0.000009 seconds
# Loop  556/2000 took: 0.000010 seconds
# Loop  557/2000 took: 0.000010 seconds
# Loop  558/2000 took: 0.000010 seconds
# Loop  559/2000 took: 0.000010 seconds
# Loop  560/2000 took: 0.000010 seconds
# Loop  561/2000 took: 0.000010 seconds
# Loop  562/2000 took: 0.000010 seconds
# Loop  563/2000 took: 0.000010 seconds
# Loop  564/2000 took: 0.000011 seconds
# Loop  565/2000 took: 0.000010 seconds
# Loop  566/2000 took: 0.000010 seconds
# Loop  567/2000 took: 0.000010 seconds
# Loop  568/2000 took: 0.000010 seconds
# Loop  569/2000 took: 0.000010 seconds
# Loop  570/2000 took: 0.000010 seconds
# Loop  571/2000 took: 0.000010 seconds
# Loop  572/2000 took: 0.000010 seconds
# Loop  573/2000 took: 0.000010 seconds
# Loop  574/2000 took: 0.000011 seconds
# Loop  575/2000 took: 0.000010 seconds
# Loop  576/2000 took: 0.000010 seconds
# Loop  577/2000 took: 0.000010 seconds
# Loop  578/2000 took: 0.000009 seconds
# Loop  579/2000 took: 0.000010 seconds
# Loop  580/2000 took: 0.000010 seconds
# Loop  581/2000 took: 0.000010 seconds
# Loop  582/2000 took: 0.000009 seconds
# Loop  583/2000 took: 0.000010 seconds
# Loop  584/2000 took: 0.000011 seconds
# Loop  585/2000 took: 0.000010 seconds
# Loop  586/2000 took: 0.000010 seconds
# Loop  587/2000 took: 0.000010 seconds
# Loop  588/2000 took: 0.000009 seconds
# Loop  589/2000 took: 0.000010 seconds
# Loop  590/2000 took: 0.000010 seconds
# Loop  591/2000 took: 0.000010 seconds
# Loop  592/2000 took: 0.000010 seconds
# Loop  593/2000 took: 0.000010 seconds
# Loop  594/2000 took: 0.000011 seconds
# Loop  595/2000 took: 0.000010 seconds
# Loop  596/2000 took: 0.000010 seconds
# Loop  597/2000 took: 0.000009 seconds
# Loop  598/2000 took: 0.000009 seconds
# Loop  599/2000 took: 0.000010 seconds
# Loop  600/2000 took: 0.000010 seconds
# Loop  601/2000 took: 0.000009 seconds
# Loop  602/2000 took: 0.000010 seconds
# Loop  603/2000 took: 0.000009 seconds
# Loop  604/2000 took: 0.000010 seconds
# Loop  605/2000 took: 0.000014 seconds
# Loop  606/2000 took: 0.000010 seconds
# Loop  607/2000 took: 0.000009 seconds
# Loop  608/2000 took: 0.000009 seconds
# Loop  609/2000 took: 0.000010 seconds
# Loop  610/2000 took: 0.000010 seconds
# Loop  611/2000 took: 0.000010 seconds
# Loop  612/2000 took: 0.000010 seconds
# Loop  613/2000 took: 0.000009 seconds
# Loop  614/2000 took: 0.000009 seconds
# Loop  615/2000 took: 0.000011 seconds
# Loop  616/2000 took: 0.000010 seconds
# Loop  617/2000 took: 0.000009 seconds
# Loop  618/2000 took: 0.000009 seconds
# Loop  619/2000 took: 0.000009 seconds
# Loop  620/2000 took: 0.000010 seconds
# Loop  621/2000 took: 0.000010 seconds
# Loop  622/2000 took: 0.000010 seconds
# Loop  623/2000 took: 0.000017 seconds
# Loop  624/2000 took: 0.000010 seconds
# Loop  625/2000 took: 0.000011 seconds
# Loop  626/2000 took: 0.000010 seconds
# Loop  627/2000 took: 0.000031 seconds
# Loop  628/2000 took: 0.000016 seconds
# Loop  629/2000 took: 0.000012 seconds
# Loop  630/2000 took: 0.000012 seconds
# Loop  631/2000 took: 0.000011 seconds
# Loop  632/2000 took: 0.000011 seconds
# Loop  633/2000 took: 0.000011 seconds
# Loop  634/2000 took: 0.000010 seconds
# Loop  635/2000 took: 0.000013 seconds
# Loop  636/2000 took: 0.000011 seconds
# Loop  637/2000 took: 0.000010 seconds
# Loop  638/2000 took: 0.000010 seconds
# Loop  639/2000 took: 0.000010 seconds
# Loop  640/2000 took: 0.000010 seconds
# Loop  641/2000 took: 0.000010 seconds
# Loop  642/2000 took: 0.000010 seconds
# Loop  643/2000 took: 0.000010 seconds
# Loop  644/2000 took: 0.000010 seconds
# Loop  645/2000 took: 0.000039 seconds
# Loop  646/2000 took: 0.000023 seconds
# Loop  647/2000 took: 0.000014 seconds
# Loop  648/2000 took: 0.000012 seconds
# Loop  649/2000 took: 0.000012 seconds
# Loop  650/2000 took: 0.000011 seconds
# Loop  651/2000 took: 0.000011 seconds
# Loop  652/2000 took: 0.000011 seconds
# Loop  653/2000 took: 0.000011 seconds
# Loop  654/2000 took: 0.000011 seconds
# Loop  655/2000 took: 0.000010 seconds
# Loop  656/2000 took: 0.000012 seconds
# Loop  657/2000 took: 0.000011 seconds
# Loop  658/2000 took: 0.000010 seconds
# Loop  659/2000 took: 0.000010 seconds
# Loop  660/2000 took: 0.000010 seconds
# Loop  661/2000 took: 0.000010 seconds
# Loop  662/2000 took: 0.000010 seconds
# Loop  663/2000 took: 0.000010 seconds
# Loop  664/2000 took: 0.000010 seconds
# Loop  665/2000 took: 0.000010 seconds
# Loop  666/2000 took: 0.000012 seconds
# Loop  667/2000 took: 0.000011 seconds
# Loop  668/2000 took: 0.000010 seconds
# Loop  669/2000 took: 0.000010 seconds
# Loop  670/2000 took: 0.000010 seconds
# Loop  671/2000 took: 0.000010 seconds
# Loop  672/2000 took: 0.000010 seconds
# Loop  673/2000 took: 0.000010 seconds
# Loop  674/2000 took: 0.000010 seconds
# Loop  675/2000 took: 0.000010 seconds
# Loop  676/2000 took: 0.000011 seconds
# Loop  677/2000 took: 0.000010 seconds
# Loop  678/2000 took: 0.000010 seconds
# Loop  679/2000 took: 0.000010 seconds
# Loop  680/2000 took: 0.000010 seconds
# Loop  681/2000 took: 0.000010 seconds
# Loop  682/2000 took: 0.000010 seconds
# Loop  683/2000 took: 0.000010 seconds
# Loop  684/2000 took: 0.000010 seconds
# Loop  685/2000 took: 0.000010 seconds
# Loop  686/2000 took: 0.000010 seconds
# Loop  687/2000 took: 0.000011 seconds
# Loop  688/2000 took: 0.000010 seconds
# Loop  689/2000 took: 0.000010 seconds
# Loop  690/2000 took: 0.000010 seconds
# Loop  691/2000 took: 0.000010 seconds
# Loop  692/2000 took: 0.000010 seconds
# Loop  693/2000 took: 0.000010 seconds
# Loop  694/2000 took: 0.000010 seconds
# Loop  695/2000 took: 0.000010 seconds
# Loop  696/2000 took: 0.000010 seconds
# Loop  697/2000 took: 0.000011 seconds
# Loop  698/2000 took: 0.000010 seconds
# Loop  699/2000 took: 0.000010 seconds
# Loop  700/2000 took: 0.000010 seconds
# Loop  701/2000 took: 0.000010 seconds
# Loop  702/2000 took: 0.000010 seconds
# Loop  703/2000 took: 0.000010 seconds
# Loop  704/2000 took: 0.000010 seconds
# Loop  705/2000 took: 0.000010 seconds
# Loop  706/2000 took: 0.000010 seconds
# Loop  707/2000 took: 0.000011 seconds
# Loop  708/2000 took: 0.000011 seconds
# Loop  709/2000 took: 0.000010 seconds
# Loop  710/2000 took: 0.000010 seconds
# Loop  711/2000 took: 0.000010 seconds
# Loop  712/2000 took: 0.000010 seconds
# Loop  713/2000 took: 0.000010 seconds
# Loop  714/2000 took: 0.000010 seconds
# Loop  715/2000 took: 0.000010 seconds
# Loop  716/2000 took: 0.000010 seconds
# Loop  717/2000 took: 0.000011 seconds
# Loop  718/2000 took: 0.000010 seconds
# Loop  719/2000 took: 0.000010 seconds
# Loop  720/2000 took: 0.000010 seconds
# Loop  721/2000 took: 0.000010 seconds
# Loop  722/2000 took: 0.000010 seconds
# Loop  723/2000 took: 0.000010 seconds
# Loop  724/2000 took: 0.000010 seconds
# Loop  725/2000 took: 0.000010 seconds
# Loop  726/2000 took: 0.000010 seconds
# Loop  727/2000 took: 0.000010 seconds
# Loop  728/2000 took: 0.000011 seconds
# Loop  729/2000 took: 0.000010 seconds
# Loop  730/2000 took: 0.000010 seconds
# Loop  731/2000 took: 0.000010 seconds
# Loop  732/2000 took: 0.000010 seconds
# Loop  733/2000 took: 0.000010 seconds
# Loop  734/2000 took: 0.000010 seconds
# Loop  735/2000 took: 0.000010 seconds
# Loop  736/2000 took: 0.000010 seconds
# Loop  737/2000 took: 0.000010 seconds
# Loop  738/2000 took: 0.000011 seconds
# Loop  739/2000 took: 0.000010 seconds
# Loop  740/2000 took: 0.000010 seconds
# Loop  741/2000 took: 0.000010 seconds
# Loop  742/2000 took: 0.000010 seconds
# Loop  743/2000 took: 0.000010 seconds
# Loop  744/2000 took: 0.000010 seconds
# Loop  745/2000 took: 0.000010 seconds
# Loop  746/2000 took: 0.000010 seconds
# Loop  747/2000 took: 0.000010 seconds
# Loop  748/2000 took: 0.000012 seconds
# Loop  749/2000 took: 0.000010 seconds
# Loop  750/2000 took: 0.000010 seconds
# Loop  751/2000 took: 0.000010 seconds
# Loop  752/2000 took: 0.000010 seconds
# Loop  753/2000 took: 0.000010 seconds
# Loop  754/2000 took: 0.000010 seconds
# Loop  755/2000 took: 0.000010 seconds
# Loop  756/2000 took: 0.000010 seconds
# Loop  757/2000 took: 0.000010 seconds
# Loop  758/2000 took: 0.000011 seconds
# Loop  759/2000 took: 0.000010 seconds
# Loop  760/2000 took: 0.000010 seconds
# Loop  761/2000 took: 0.000010 seconds
# Loop  762/2000 took: 0.000010 seconds
# Loop  763/2000 took: 0.000010 seconds
# Loop  764/2000 took: 0.000010 seconds
# Loop  765/2000 took: 0.000010 seconds
# Loop  766/2000 took: 0.000010 seconds
# Loop  767/2000 took: 0.000010 seconds
# Loop  768/2000 took: 0.000010 seconds
# Loop  769/2000 took: 0.000012 seconds
# Loop  770/2000 took: 0.000010 seconds
# Loop  771/2000 took: 0.000010 seconds
# Loop  772/2000 took: 0.000010 seconds
# Loop  773/2000 took: 0.000010 seconds
# Loop  774/2000 took: 0.000010 seconds
# Loop  775/2000 took: 0.000010 seconds
# Loop  776/2000 took: 0.000010 seconds
# Loop  777/2000 took: 0.000010 seconds
# Loop  778/2000 took: 0.000010 seconds
# Loop  779/2000 took: 0.000011 seconds
# Loop  780/2000 took: 0.000010 seconds
# Loop  781/2000 took: 0.000010 seconds
# Loop  782/2000 took: 0.000010 seconds
# Loop  783/2000 took: 0.000010 seconds
# Loop  784/2000 took: 0.000010 seconds
# Loop  785/2000 took: 0.000014 seconds
# Loop  786/2000 took: 0.000010 seconds
# Loop  787/2000 took: 0.000010 seconds
# Loop  788/2000 took: 0.000010 seconds
# Loop  789/2000 took: 0.000011 seconds
# Loop  790/2000 took: 0.000010 seconds
# Loop  791/2000 took: 0.000010 seconds
# Loop  792/2000 took: 0.000010 seconds
# Loop  793/2000 took: 0.000010 seconds
# Loop  794/2000 took: 0.000010 seconds
# Loop  795/2000 took: 0.000010 seconds
# Loop  796/2000 took: 0.000010 seconds
# Loop  797/2000 took: 0.000010 seconds
# Loop  798/2000 took: 0.000010 seconds
# Loop  799/2000 took: 0.000011 seconds
# Loop  800/2000 took: 0.000010 seconds
# Loop  801/2000 took: 0.000010 seconds
# Loop  802/2000 took: 0.000010 seconds
# Loop  803/2000 took: 0.000144 seconds
# Loop  804/2000 took: 0.000019 seconds
# Loop  805/2000 took: 0.000013 seconds
# Loop  806/2000 took: 0.000012 seconds
# Loop  807/2000 took: 0.000011 seconds
# Loop  808/2000 took: 0.000011 seconds
# Loop  809/2000 took: 0.000016 seconds
# Loop  810/2000 took: 0.000012 seconds
# Loop  811/2000 took: 0.000011 seconds
# Loop  812/2000 took: 0.000010 seconds
# Loop  813/2000 took: 0.000010 seconds
# Loop  814/2000 took: 0.000010 seconds
# Loop  815/2000 took: 0.000010 seconds
# Loop  816/2000 took: 0.000010 seconds
# Loop  817/2000 took: 0.000010 seconds
# Loop  818/2000 took: 0.000010 seconds
# Loop  819/2000 took: 0.000010 seconds
# Loop  820/2000 took: 0.000012 seconds
# Loop  821/2000 took: 0.000011 seconds
# Loop  822/2000 took: 0.000010 seconds
# Loop  823/2000 took: 0.000010 seconds
# Loop  824/2000 took: 0.000010 seconds
# Loop  825/2000 took: 0.000010 seconds
# Loop  826/2000 took: 0.000010 seconds
# Loop  827/2000 took: 0.000010 seconds
# Loop  828/2000 took: 0.000010 seconds
# Loop  829/2000 took: 0.000010 seconds
# Loop  830/2000 took: 0.000012 seconds
# Loop  831/2000 took: 0.000010 seconds
# Loop  832/2000 took: 0.000010 seconds
# Loop  833/2000 took: 0.000010 seconds
# Loop  834/2000 took: 0.000010 seconds
# Loop  835/2000 took: 0.000010 seconds
# Loop  836/2000 took: 0.000010 seconds
# Loop  837/2000 took: 0.000010 seconds
# Loop  838/2000 took: 0.000010 seconds
# Loop  839/2000 took: 0.000010 seconds
# Loop  840/2000 took: 0.000012 seconds
# Loop  841/2000 took: 0.000010 seconds
# Loop  842/2000 took: 0.000010 seconds
# Loop  843/2000 took: 0.000010 seconds
# Loop  844/2000 took: 0.000010 seconds
# Loop  845/2000 took: 0.000010 seconds
# Loop  846/2000 took: 0.000010 seconds
# Loop  847/2000 took: 0.000010 seconds
# Loop  848/2000 took: 0.000010 seconds
# Loop  849/2000 took: 0.000010 seconds
# Loop  850/2000 took: 0.000014 seconds
# Loop  851/2000 took: 0.000010 seconds
# Loop  852/2000 took: 0.000010 seconds
# Loop  853/2000 took: 0.000010 seconds
# Loop  854/2000 took: 0.000010 seconds
# Loop  855/2000 took: 0.000010 seconds
# Loop  856/2000 took: 0.000010 seconds
# Loop  857/2000 took: 0.000010 seconds
# Loop  858/2000 took: 0.000010 seconds
# Loop  859/2000 took: 0.000010 seconds
# Loop  860/2000 took: 0.000010 seconds
# Loop  861/2000 took: 0.000014 seconds
# Loop  862/2000 took: 0.000010 seconds
# Loop  863/2000 took: 0.000010 seconds
# Loop  864/2000 took: 0.000010 seconds
# Loop  865/2000 took: 0.000009 seconds
# Loop  866/2000 took: 0.000010 seconds
# Loop  867/2000 took: 0.000010 seconds
# Loop  868/2000 took: 0.000010 seconds
# Loop  869/2000 took: 0.000010 seconds
# Loop  870/2000 took: 0.000010 seconds
# Loop  871/2000 took: 0.000014 seconds
# Loop  872/2000 took: 0.000010 seconds
# Loop  873/2000 took: 0.000010 seconds
# Loop  874/2000 took: 0.000010 seconds
# Loop  875/2000 took: 0.000010 seconds
# Loop  876/2000 took: 0.000010 seconds
# Loop  877/2000 took: 0.000010 seconds
# Loop  878/2000 took: 0.000010 seconds
# Loop  879/2000 took: 0.000010 seconds
# Loop  880/2000 took: 0.000010 seconds
# Loop  881/2000 took: 0.000011 seconds
# Loop  882/2000 took: 0.000010 seconds
# Loop  883/2000 took: 0.000010 seconds
# Loop  884/2000 took: 0.000010 seconds
# Loop  885/2000 took: 0.000010 seconds
# Loop  886/2000 took: 0.000010 seconds
# Loop  887/2000 took: 0.000010 seconds
# Loop  888/2000 took: 0.000010 seconds
# Loop  889/2000 took: 0.000010 seconds
# Loop  890/2000 took: 0.000009 seconds
# Loop  891/2000 took: 0.000014 seconds
# Loop  892/2000 took: 0.000010 seconds
# Loop  893/2000 took: 0.000010 seconds
# Loop  894/2000 took: 0.000010 seconds
# Loop  895/2000 took: 0.000010 seconds
# Loop  896/2000 took: 0.000010 seconds
# Loop  897/2000 took: 0.000009 seconds
# Loop  898/2000 took: 0.000010 seconds
# Loop  899/2000 took: 0.000010 seconds
# Loop  900/2000 took: 0.000010 seconds
# Loop  901/2000 took: 0.000010 seconds
# Loop  902/2000 took: 0.000014 seconds
# Loop  903/2000 took: 0.000010 seconds
# Loop  904/2000 took: 0.000010 seconds
# Loop  905/2000 took: 0.000010 seconds
# Loop  906/2000 took: 0.000009 seconds
# Loop  907/2000 took: 0.000010 seconds
# Loop  908/2000 took: 0.000009 seconds
# Loop  909/2000 took: 0.000010 seconds
# Loop  910/2000 took: 0.000009 seconds
# Loop  911/2000 took: 0.000010 seconds
# Loop  912/2000 took: 0.000014 seconds
# Loop  913/2000 took: 0.000010 seconds
# Loop  914/2000 took: 0.000010 seconds
# Loop  915/2000 took: 0.000010 seconds
# Loop  916/2000 took: 0.000010 seconds
# Loop  917/2000 took: 0.000010 seconds
# Loop  918/2000 took: 0.000010 seconds
# Loop  919/2000 took: 0.000009 seconds
# Loop  920/2000 took: 0.000010 seconds
# Loop  921/2000 took: 0.000010 seconds
# Loop  922/2000 took: 0.000012 seconds
# Loop  923/2000 took: 0.000010 seconds
# Loop  924/2000 took: 0.000010 seconds
# Loop  925/2000 took: 0.000010 seconds
# Loop  926/2000 took: 0.000010 seconds
# Loop  927/2000 took: 0.000010 seconds
# Loop  928/2000 took: 0.000010 seconds
# Loop  929/2000 took: 0.000010 seconds
# Loop  930/2000 took: 0.000010 seconds
# Loop  931/2000 took: 0.000009 seconds
# Loop  932/2000 took: 0.000017 seconds
# Loop  933/2000 took: 0.000010 seconds
# Loop  934/2000 took: 0.000010 seconds
# Loop  935/2000 took: 0.000010 seconds
# Loop  936/2000 took: 0.000010 seconds
# Loop  937/2000 took: 0.000010 seconds
# Loop  938/2000 took: 0.000009 seconds
# Loop  939/2000 took: 0.000010 seconds
# Loop  940/2000 took: 0.000010 seconds
# Loop  941/2000 took: 0.000010 seconds
# Loop  942/2000 took: 0.000010 seconds
# Loop  943/2000 took: 0.000014 seconds
# Loop  944/2000 took: 0.000010 seconds
# Loop  945/2000 took: 0.000009 seconds
# Loop  946/2000 took: 0.000009 seconds
# Loop  947/2000 took: 0.000010 seconds
# Loop  948/2000 took: 0.000010 seconds
# Loop  949/2000 took: 0.000010 seconds
# Loop  950/2000 took: 0.000010 seconds
# Loop  951/2000 took: 0.000010 seconds
# Loop  952/2000 took: 0.000010 seconds
# Loop  953/2000 took: 0.000011 seconds
# Loop  954/2000 took: 0.000010 seconds
# Loop  955/2000 took: 0.000010 seconds
# Loop  956/2000 took: 0.000010 seconds
# Loop  957/2000 took: 0.000010 seconds
# Loop  958/2000 took: 0.000009 seconds
# Loop  959/2000 took: 0.000010 seconds
# Loop  960/2000 took: 0.000010 seconds
# Loop  961/2000 took: 0.000010 seconds
# Loop  962/2000 took: 0.000010 seconds
# Loop  963/2000 took: 0.000014 seconds
# Loop  964/2000 took: 0.000010 seconds
# Loop  965/2000 took: 0.000010 seconds
# Loop  966/2000 took: 0.000010 seconds
# Loop  967/2000 took: 0.000010 seconds
# Loop  968/2000 took: 0.000010 seconds
# Loop  969/2000 took: 0.000010 seconds
# Loop  970/2000 took: 0.000010 seconds
# Loop  971/2000 took: 0.000010 seconds
# Loop  972/2000 took: 0.000010 seconds
# Loop  973/2000 took: 0.000014 seconds
# Loop  974/2000 took: 0.000010 seconds
# Loop  975/2000 took: 0.000009 seconds
# Loop  976/2000 took: 0.000010 seconds
# Loop  977/2000 took: 0.000010 seconds
# Loop  978/2000 took: 0.000010 seconds
# Loop  979/2000 took: 0.000010 seconds
# Loop  980/2000 took: 0.000010 seconds
# Loop  981/2000 took: 0.000010 seconds
# Loop  982/2000 took: 0.000010 seconds
# Loop  983/2000 took: 0.000010 seconds
# Loop  984/2000 took: 0.000014 seconds
# Loop  985/2000 took: 0.000010 seconds
# Loop  986/2000 took: 0.000010 seconds
# Loop  987/2000 took: 0.000010 seconds
# Loop  988/2000 took: 0.000010 seconds
# Loop  989/2000 took: 0.000010 seconds
# Loop  990/2000 took: 0.000010 seconds
# Loop  991/2000 took: 0.000009 seconds
# Loop  992/2000 took: 0.000010 seconds
# Loop  993/2000 took: 0.000010 seconds
# Loop  994/2000 took: 0.000014 seconds
# Loop  995/2000 took: 0.000010 seconds
# Loop  996/2000 took: 0.000010 seconds
# Loop  997/2000 took: 0.000009 seconds
# Loop  998/2000 took: 0.000010 seconds
# Loop  999/2000 took: 0.000010 seconds
# Loop 1000/2000 took: 0.000010 seconds
# Loop 1001/2000 took: 0.000010 seconds
# Loop 1002/2000 took: 0.000009 seconds
# Loop 1003/2000 took: 0.000010 seconds
# Loop 1004/2000 took: 0.000011 seconds
# Loop 1005/2000 took: 0.000010 seconds
# Loop 1006/2000 took: 0.000010 seconds
# Loop 1007/2000 took: 0.000010 seconds
# Loop 1008/2000 took: 0.000022 seconds
# Loop 1009/2000 took: 0.000010 seconds
# Loop 1010/2000 took: 0.000010 seconds
# Loop 1011/2000 took: 0.000010 seconds
# Loop 1012/2000 took: 0.000010 seconds
# Loop 1013/2000 took: 0.000010 seconds
# Loop 1014/2000 took: 0.000012 seconds
# Loop 1015/2000 took: 0.000010 seconds
# Loop 1016/2000 took: 0.000010 seconds
# Loop 1017/2000 took: 0.000010 seconds
# Loop 1018/2000 took: 0.000010 seconds
# Loop 1019/2000 took: 0.000010 seconds
# Loop 1020/2000 took: 0.000010 seconds
# Loop 1021/2000 took: 0.000010 seconds
# Loop 1022/2000 took: 0.000010 seconds
# Loop 1023/2000 took: 0.000010 seconds
# Loop 1024/2000 took: 0.000010 seconds
# Loop 1025/2000 took: 0.000011 seconds
# Loop 1026/2000 took: 0.000010 seconds
# Loop 1027/2000 took: 0.000010 seconds
# Loop 1028/2000 took: 0.000010 seconds
# Loop 1029/2000 took: 0.000010 seconds
# Loop 1030/2000 took: 0.000010 seconds
# Loop 1031/2000 took: 0.000010 seconds
# Loop 1032/2000 took: 0.000010 seconds
# Loop 1033/2000 took: 0.000010 seconds
# Loop 1034/2000 took: 0.000010 seconds
# Loop 1035/2000 took: 0.000011 seconds
# Loop 1036/2000 took: 0.000010 seconds
# Loop 1037/2000 took: 0.000010 seconds
# Loop 1038/2000 took: 0.000010 seconds
# Loop 1039/2000 took: 0.000010 seconds
# Loop 1040/2000 took: 0.000010 seconds
# Loop 1041/2000 took: 0.000010 seconds
# Loop 1042/2000 took: 0.000010 seconds
# Loop 1043/2000 took: 0.000010 seconds
# Loop 1044/2000 took: 0.000009 seconds
# Loop 1045/2000 took: 0.000011 seconds
# Loop 1046/2000 took: 0.000010 seconds
# Loop 1047/2000 took: 0.000010 seconds
# Loop 1048/2000 took: 0.000010 seconds
# Loop 1049/2000 took: 0.000010 seconds
# Loop 1050/2000 took: 0.000010 seconds
# Loop 1051/2000 took: 0.000010 seconds
# Loop 1052/2000 took: 0.000009 seconds
# Loop 1053/2000 took: 0.000010 seconds
# Loop 1054/2000 took: 0.000010 seconds
# Loop 1055/2000 took: 0.000011 seconds
# Loop 1056/2000 took: 0.000010 seconds
# Loop 1057/2000 took: 0.000010 seconds
# Loop 1058/2000 took: 0.000010 seconds
# Loop 1059/2000 took: 0.000010 seconds
# Loop 1060/2000 took: 0.000010 seconds
# Loop 1061/2000 took: 0.000010 seconds
# Loop 1062/2000 took: 0.000010 seconds
# Loop 1063/2000 took: 0.000010 seconds
# Loop 1064/2000 took: 0.000010 seconds
# Loop 1065/2000 took: 0.000011 seconds
# Loop 1066/2000 took: 0.000010 seconds
# Loop 1067/2000 took: 0.000010 seconds
# Loop 1068/2000 took: 0.000010 seconds
# Loop 1069/2000 took: 0.000009 seconds
# Loop 1070/2000 took: 0.000010 seconds
# Loop 1071/2000 took: 0.000010 seconds
# Loop 1072/2000 took: 0.000010 seconds
# Loop 1073/2000 took: 0.000010 seconds
# Loop 1074/2000 took: 0.000010 seconds
# Loop 1075/2000 took: 0.000010 seconds
# Loop 1076/2000 took: 0.000011 seconds
# Loop 1077/2000 took: 0.000010 seconds
# Loop 1078/2000 took: 0.000009 seconds
# Loop 1079/2000 took: 0.000010 seconds
# Loop 1080/2000 took: 0.000010 seconds
# Loop 1081/2000 took: 0.000010 seconds
# Loop 1082/2000 took: 0.000010 seconds
# Loop 1083/2000 took: 0.000010 seconds
# Loop 1084/2000 took: 0.000009 seconds
# Loop 1085/2000 took: 0.000010 seconds
# Loop 1086/2000 took: 0.000012 seconds
# Loop 1087/2000 took: 0.000010 seconds
# Loop 1088/2000 took: 0.000010 seconds
# Loop 1089/2000 took: 0.000010 seconds
# Loop 1090/2000 took: 0.000009 seconds
# Loop 1091/2000 took: 0.000010 seconds
# Loop 1092/2000 took: 0.000010 seconds
# Loop 1093/2000 took: 0.000010 seconds
# Loop 1094/2000 took: 0.000010 seconds
# Loop 1095/2000 took: 0.000009 seconds
# Loop 1096/2000 took: 0.000011 seconds
# Loop 1097/2000 took: 0.000010 seconds
# Loop 1098/2000 took: 0.000010 seconds
# Loop 1099/2000 took: 0.000010 seconds
# Loop 1100/2000 took: 0.000010 seconds
# Loop 1101/2000 took: 0.000010 seconds
# Loop 1102/2000 took: 0.000010 seconds
# Loop 1103/2000 took: 0.000010 seconds
# Loop 1104/2000 took: 0.000010 seconds
# Loop 1105/2000 took: 0.000010 seconds
# Loop 1106/2000 took: 0.000011 seconds
# Loop 1107/2000 took: 0.000010 seconds
# Loop 1108/2000 took: 0.000010 seconds
# Loop 1109/2000 took: 0.000010 seconds
# Loop 1110/2000 took: 0.000009 seconds
# Loop 1111/2000 took: 0.000010 seconds
# Loop 1112/2000 took: 0.000010 seconds
# Loop 1113/2000 took: 0.000010 seconds
# Loop 1114/2000 took: 0.000010 seconds
# Loop 1115/2000 took: 0.000010 seconds
# Loop 1116/2000 took: 0.000010 seconds
# Loop 1117/2000 took: 0.000011 seconds
# Loop 1118/2000 took: 0.000010 seconds
# Loop 1119/2000 took: 0.000009 seconds
# Loop 1120/2000 took: 0.000010 seconds
# Loop 1121/2000 took: 0.000010 seconds
# Loop 1122/2000 took: 0.000010 seconds
# Loop 1123/2000 took: 0.000010 seconds
# Loop 1124/2000 took: 0.000010 seconds
# Loop 1125/2000 took: 0.000010 seconds
# Loop 1126/2000 took: 0.000010 seconds
# Loop 1127/2000 took: 0.000011 seconds
# Loop 1128/2000 took: 0.000010 seconds
# Loop 1129/2000 took: 0.000010 seconds
# Loop 1130/2000 took: 0.000010 seconds
# Loop 1131/2000 took: 0.000010 seconds
# Loop 1132/2000 took: 0.000010 seconds
# Loop 1133/2000 took: 0.000010 seconds
# Loop 1134/2000 took: 0.000009 seconds
# Loop 1135/2000 took: 0.000010 seconds
# Loop 1136/2000 took: 0.000010 seconds
# Loop 1137/2000 took: 0.000011 seconds
# Loop 1138/2000 took: 0.000010 seconds
# Loop 1139/2000 took: 0.000010 seconds
# Loop 1140/2000 took: 0.000010 seconds
# Loop 1141/2000 took: 0.000010 seconds
# Loop 1142/2000 took: 0.000010 seconds
# Loop 1143/2000 took: 0.000010 seconds
# Loop 1144/2000 took: 0.000010 seconds
# Loop 1145/2000 took: 0.000010 seconds
# Loop 1146/2000 took: 0.000010 seconds
# Loop 1147/2000 took: 0.000013 seconds
# Loop 1148/2000 took: 0.000010 seconds
# Loop 1149/2000 took: 0.000010 seconds
# Loop 1150/2000 took: 0.000010 seconds
# Loop 1151/2000 took: 0.000010 seconds
# Loop 1152/2000 took: 0.000010 seconds
# Loop 1153/2000 took: 0.000010 seconds
# Loop 1154/2000 took: 0.000010 seconds
# Loop 1155/2000 took: 0.000010 seconds
# Loop 1156/2000 took: 0.000010 seconds
# Loop 1157/2000 took: 0.000010 seconds
# Loop 1158/2000 took: 0.000012 seconds
# Loop 1159/2000 took: 0.000010 seconds
# Loop 1160/2000 took: 0.000010 seconds
# Loop 1161/2000 took: 0.000010 seconds
# Loop 1162/2000 took: 0.000009 seconds
# Loop 1163/2000 took: 0.000010 seconds
# Loop 1164/2000 took: 0.000010 seconds
# Loop 1165/2000 took: 0.000010 seconds
# Loop 1166/2000 took: 0.000010 seconds
# Loop 1167/2000 took: 0.000009 seconds
# Loop 1168/2000 took: 0.000013 seconds
# Loop 1169/2000 took: 0.000010 seconds
# Loop 1170/2000 took: 0.000010 seconds
# Loop 1171/2000 took: 0.000010 seconds
# Loop 1172/2000 took: 0.000010 seconds
# Loop 1173/2000 took: 0.000010 seconds
# Loop 1174/2000 took: 0.000010 seconds
# Loop 1175/2000 took: 0.000010 seconds
# Loop 1176/2000 took: 0.000009 seconds
# Loop 1177/2000 took: 0.000010 seconds
# Loop 1178/2000 took: 0.000011 seconds
# Loop 1179/2000 took: 0.000010 seconds
# Loop 1180/2000 took: 0.000010 seconds
# Loop 1181/2000 took: 0.000010 seconds
# Loop 1182/2000 took: 0.000010 seconds
# Loop 1183/2000 took: 0.000010 seconds
# Loop 1184/2000 took: 0.000010 seconds
# Loop 1185/2000 took: 0.000010 seconds
# Loop 1186/2000 took: 0.000010 seconds
# Loop 1187/2000 took: 0.000010 seconds
# Loop 1188/2000 took: 0.000011 seconds
# Loop 1189/2000 took: 0.000010 seconds
# Loop 1190/2000 took: 0.000023 seconds
# Loop 1191/2000 took: 0.000010 seconds
# Loop 1192/2000 took: 0.000010 seconds
# Loop 1193/2000 took: 0.000010 seconds
# Loop 1194/2000 took: 0.000010 seconds
# Loop 1195/2000 took: 0.000010 seconds
# Loop 1196/2000 took: 0.000009 seconds
# Loop 1197/2000 took: 0.000010 seconds
# Loop 1198/2000 took: 0.000010 seconds
# Loop 1199/2000 took: 0.000011 seconds
# Loop 1200/2000 took: 0.000010 seconds
# Loop 1201/2000 took: 0.000010 seconds
# Loop 1202/2000 took: 0.000010 seconds
# Loop 1203/2000 took: 0.000010 seconds
# Loop 1204/2000 took: 0.000010 seconds
# Loop 1205/2000 took: 0.000010 seconds
# Loop 1206/2000 took: 0.000010 seconds
# Loop 1207/2000 took: 0.000010 seconds
# Loop 1208/2000 took: 0.000010 seconds
# Loop 1209/2000 took: 0.000011 seconds
# Loop 1210/2000 took: 0.000010 seconds
# Loop 1211/2000 took: 0.000010 seconds
# Loop 1212/2000 took: 0.000010 seconds
# Loop 1213/2000 took: 0.000010 seconds
# Loop 1214/2000 took: 0.000010 seconds
# Loop 1215/2000 took: 0.000010 seconds
# Loop 1216/2000 took: 0.000010 seconds
# Loop 1217/2000 took: 0.000009 seconds
# Loop 1218/2000 took: 0.000010 seconds
# Loop 1219/2000 took: 0.000011 seconds
# Loop 1220/2000 took: 0.000010 seconds
# Loop 1221/2000 took: 0.000010 seconds
# Loop 1222/2000 took: 0.000010 seconds
# Loop 1223/2000 took: 0.000010 seconds
# Loop 1224/2000 took: 0.000010 seconds
# Loop 1225/2000 took: 0.000010 seconds
# Loop 1226/2000 took: 0.000010 seconds
# Loop 1227/2000 took: 0.000009 seconds
# Loop 1228/2000 took: 0.000009 seconds
# Loop 1229/2000 took: 0.000011 seconds
# Loop 1230/2000 took: 0.000010 seconds
# Loop 1231/2000 took: 0.000010 seconds
# Loop 1232/2000 took: 0.000010 seconds
# Loop 1233/2000 took: 0.000009 seconds
# Loop 1234/2000 took: 0.000010 seconds
# Loop 1235/2000 took: 0.000010 seconds
# Loop 1236/2000 took: 0.000010 seconds
# Loop 1237/2000 took: 0.000009 seconds
# Loop 1238/2000 took: 0.000010 seconds
# Loop 1239/2000 took: 0.000010 seconds
# Loop 1240/2000 took: 0.000014 seconds
# Loop 1241/2000 took: 0.000010 seconds
# Loop 1242/2000 took: 0.000010 seconds
# Loop 1243/2000 took: 0.000010 seconds
# Loop 1244/2000 took: 0.000009 seconds
# Loop 1245/2000 took: 0.000010 seconds
# Loop 1246/2000 took: 0.000010 seconds
# Loop 1247/2000 took: 0.000010 seconds
# Loop 1248/2000 took: 0.000010 seconds
# Loop 1249/2000 took: 0.000010 seconds
# Loop 1250/2000 took: 0.000011 seconds
# Loop 1251/2000 took: 0.000010 seconds
# Loop 1252/2000 took: 0.000010 seconds
# Loop 1253/2000 took: 0.000010 seconds
# Loop 1254/2000 took: 0.000010 seconds
# Loop 1255/2000 took: 0.000010 seconds
# Loop 1256/2000 took: 0.000010 seconds
# Loop 1257/2000 took: 0.000010 seconds
# Loop 1258/2000 took: 0.000010 seconds
# Loop 1259/2000 took: 0.000010 seconds
# Loop 1260/2000 took: 0.000013 seconds
# Loop 1261/2000 took: 0.000010 seconds
# Loop 1262/2000 took: 0.000010 seconds
# Loop 1263/2000 took: 0.000009 seconds
# ...
# Loop 1582/2000 took: 0.000010 seconds
# Loop 1583/2000 took: 0.000010 seconds
# Loop 1584/2000 took: 0.000010 seconds
# Loop 1585/2000 took: 0.000010 seconds
# Loop 1586/2000 took: 0.000010 seconds
# Loop 1587/2000 took: 0.000010 seconds
# Loop 1588/2000 took: 0.000012 seconds
# Loop 1589/2000 took: 0.000010 seconds
# Loop 1590/2000 took: 0.000010 seconds
# Loop 1591/2000 took: 0.000010 seconds
# Loop 1592/2000 took: 0.000010 seconds
# Loop 1593/2000 took: 0.000010 seconds
# Loop 1594/2000 took: 0.000010 seconds
# Loop 1595/2000 took: 0.000010 seconds
# Loop 1596/2000 took: 0.000010 seconds
# Loop 1597/2000 took: 0.000010 seconds
# Loop 1598/2000 took: 0.000011 seconds
# Loop 1599/2000 took: 0.000010 seconds
# Loop 1600/2000 took: 0.000010 seconds
# Loop 1601/2000 took: 0.000010 seconds
# Loop 1602/2000 took: 0.000010 seconds
# Loop 1603/2000 took: 0.000010 seconds
# Loop 1604/2000 took: 0.000010 seconds
# Loop 1605/2000 took: 0.000010 seconds
# Loop 1606/2000 took: 0.000010 seconds
# Loop 1607/2000 took: 0.000010 seconds
# Loop 1608/2000 took: 0.000011 seconds
# Loop 1609/2000 took: 0.000017 seconds
# Loop 1610/2000 took: 0.000010 seconds
# Loop 1611/2000 took: 0.000010 seconds
# Loop 1612/2000 took: 0.000010 seconds
# Loop 1613/2000 took: 0.000010 seconds
# Loop 1614/2000 took: 0.000010 seconds
# Loop 1615/2000 took: 0.000010 seconds
# Loop 1616/2000 took: 0.000010 seconds
# Loop 1617/2000 took: 0.000010 seconds
# Loop 1618/2000 took: 0.000014 seconds
# Loop 1619/2000 took: 0.000010 seconds
# Loop 1620/2000 took: 0.000010 seconds
# Loop 1621/2000 took: 0.000010 seconds
# Loop 1622/2000 took: 0.000010 seconds
# Loop 1623/2000 took: 0.000010 seconds
# Loop 1624/2000 took: 0.000010 seconds
# Loop 1625/2000 took: 0.000010 seconds
# Loop 1626/2000 took: 0.000010 seconds
# Loop 1627/2000 took: 0.000010 seconds
# Loop 1628/2000 took: 0.000010 seconds
# Loop 1629/2000 took: 0.000011 seconds
# Loop 1630/2000 took: 0.000010 seconds
# Loop 1631/2000 took: 0.000010 seconds
# Loop 1632/2000 took: 0.000010 seconds
# Loop 1633/2000 took: 0.000010 seconds
# Loop 1634/2000 took: 0.000010 seconds
# Loop 1635/2000 took: 0.000010 seconds
# Loop 1636/2000 took: 0.000010 seconds
# Loop 1637/2000 took: 0.000010 seconds
# Loop 1638/2000 took: 0.000010 seconds
# Loop 1639/2000 took: 0.000014 seconds
# Loop 1640/2000 took: 0.000010 seconds
# Loop 1641/2000 took: 0.000010 seconds
# Loop 1642/2000 took: 0.000010 seconds
# Loop 1643/2000 took: 0.000010 seconds
# Loop 1644/2000 took: 0.000010 seconds
# Loop 1645/2000 took: 0.000010 seconds
# Loop 1646/2000 took: 0.000010 seconds
# Loop 1647/2000 took: 0.000010 seconds
# Loop 1648/2000 took: 0.000009 seconds
# Loop 1649/2000 took: 0.000012 seconds
# Loop 1650/2000 took: 0.000010 seconds
# Loop 1651/2000 took: 0.000010 seconds
# Loop 1652/2000 took: 0.000010 seconds
# Loop 1653/2000 took: 0.000010 seconds
# Loop 1654/2000 took: 0.000010 seconds
# Loop 1655/2000 took: 0.000010 seconds
# Loop 1656/2000 took: 0.000010 seconds
# Loop 1657/2000 took: 0.000010 seconds
# Loop 1658/2000 took: 0.000010 seconds
# Loop 1659/2000 took: 0.000014 seconds
# Loop 1660/2000 took: 0.000010 seconds
# Loop 1661/2000 took: 0.000010 seconds
# Loop 1662/2000 took: 0.000010 seconds
# Loop 1663/2000 took: 0.000010 seconds
# Loop 1664/2000 took: 0.000010 seconds
# Loop 1665/2000 took: 0.000010 seconds
# Loop 1666/2000 took: 0.000010 seconds
# Loop 1667/2000 took: 0.000010 seconds
# Loop 1668/2000 took: 0.000010 seconds
# Loop 1669/2000 took: 0.000010 seconds
# Loop 1670/2000 took: 0.000011 seconds
# Loop 1671/2000 took: 0.000010 seconds
# Loop 1672/2000 took: 0.000010 seconds
# Loop 1673/2000 took: 0.000010 seconds
# Loop 1674/2000 took: 0.000010 seconds
# Loop 1675/2000 took: 0.000010 seconds
# Loop 1676/2000 took: 0.000010 seconds
# Loop 1677/2000 took: 0.000010 seconds
# Loop 1678/2000 took: 0.000010 seconds
# Loop 1679/2000 took: 0.000010 seconds
# Loop 1680/2000 took: 0.000011 seconds
# Loop 1681/2000 took: 0.000010 seconds
# Loop 1682/2000 took: 0.000010 seconds
# Loop 1683/2000 took: 0.000010 seconds
# Loop 1684/2000 took: 0.000010 seconds
# Loop 1685/2000 took: 0.000010 seconds
# Loop 1686/2000 took: 0.000009 seconds
# Loop 1687/2000 took: 0.000010 seconds
# Loop 1688/2000 took: 0.000010 seconds
# Loop 1689/2000 took: 0.000010 seconds
# Loop 1690/2000 took: 0.000011 seconds
# Loop 1691/2000 took: 0.000010 seconds
# Loop 1692/2000 took: 0.000010 seconds
# Loop 1693/2000 took: 0.000010 seconds
# Loop 1694/2000 took: 0.000010 seconds
# Loop 1695/2000 took: 0.000010 seconds
# Loop 1696/2000 took: 0.000010 seconds
# Loop 1697/2000 took: 0.000010 seconds
# Loop 1698/2000 took: 0.000010 seconds
# Loop 1699/2000 took: 0.000010 seconds
# Loop 1700/2000 took: 0.000012 seconds
# Loop 1701/2000 took: 0.000010 seconds
# Loop 1702/2000 took: 0.000010 seconds
# Loop 1703/2000 took: 0.000010 seconds
# Loop 1704/2000 took: 0.000010 seconds
# Loop 1705/2000 took: 0.000010 seconds
# Loop 1706/2000 took: 0.000010 seconds
# Loop 1707/2000 took: 0.000019 seconds
# Loop 1708/2000 took: 0.000010 seconds
# Loop 1709/2000 took: 0.000010 seconds
# Loop 1710/2000 took: 0.000010 seconds
# Loop 1711/2000 took: 0.000012 seconds
# Loop 1712/2000 took: 0.000010 seconds
# Loop 1713/2000 took: 0.000010 seconds
# Loop 1714/2000 took: 0.000010 seconds
# Loop 1715/2000 took: 0.000010 seconds
# Loop 1716/2000 took: 0.000010 seconds
# Loop 1717/2000 took: 0.000010 seconds
# Loop 1718/2000 took: 0.000010 seconds
# Loop 1719/2000 took: 0.000010 seconds
# Loop 1720/2000 took: 0.000010 seconds
# Loop 1721/2000 took: 0.000011 seconds
# Loop 1722/2000 took: 0.000010 seconds
# Loop 1723/2000 took: 0.000010 seconds
# Loop 1724/2000 took: 0.000010 seconds
# Loop 1725/2000 took: 0.000010 seconds
# Loop 1726/2000 took: 0.000010 seconds
# Loop 1727/2000 took: 0.000009 seconds
# Loop 1728/2000 took: 0.000010 seconds
# Loop 1729/2000 took: 0.000010 seconds
# Loop 1730/2000 took: 0.000010 seconds
# Loop 1731/2000 took: 0.000011 seconds
# Loop 1732/2000 took: 0.000010 seconds
# Loop 1733/2000 took: 0.000010 seconds
# Loop 1734/2000 took: 0.000010 seconds
# Loop 1735/2000 took: 0.000010 seconds
# Loop 1736/2000 took: 0.000010 seconds
# Loop 1737/2000 took: 0.000010 seconds
# Loop 1738/2000 took: 0.000010 seconds
# Loop 1739/2000 took: 0.000010 seconds
# Loop 1740/2000 took: 0.000010 seconds
# Loop 1741/2000 took: 0.000012 seconds
# Loop 1742/2000 took: 0.000010 seconds
# Loop 1743/2000 took: 0.000010 seconds
# Loop 1744/2000 took: 0.000010 seconds
# Loop 1745/2000 took: 0.000009 seconds
# Loop 1746/2000 took: 0.000010 seconds
# Loop 1747/2000 took: 0.000009 seconds
# Loop 1748/2000 took: 0.000010 seconds
# Loop 1749/2000 took: 0.000010 seconds
# Loop 1750/2000 took: 0.000010 seconds
# Loop 1751/2000 took: 0.000010 seconds
# Loop 1752/2000 took: 0.000011 seconds
# Loop 1753/2000 took: 0.000010 seconds
# Loop 1754/2000 took: 0.000010 seconds
# Loop 1755/2000 took: 0.000010 seconds
# Loop 1756/2000 took: 0.000010 seconds
# Loop 1757/2000 took: 0.000009 seconds
# Loop 1758/2000 took: 0.000010 seconds
# Loop 1759/2000 took: 0.000010 seconds
# Loop 1760/2000 took: 0.000010 seconds
# Loop 1761/2000 took: 0.000010 seconds
# Loop 1762/2000 took: 0.000011 seconds
# Loop 1763/2000 took: 0.000010 seconds
# Loop 1764/2000 took: 0.000010 seconds
# Loop 1765/2000 took: 0.000010 seconds
# Loop 1766/2000 took: 0.000010 seconds
# Loop 1767/2000 took: 0.000010 seconds
# Loop 1768/2000 took: 0.000010 seconds
# Loop 1769/2000 took: 0.000010 seconds
# Loop 1770/2000 took: 0.000010 seconds
# Loop 1771/2000 took: 0.000010 seconds
# Loop 1772/2000 took: 0.000011 seconds
# Loop 1773/2000 took: 0.000010 seconds
# Loop 1774/2000 took: 0.000010 seconds
# Loop 1775/2000 took: 0.000010 seconds
# Loop 1776/2000 took: 0.000010 seconds
# Loop 1777/2000 took: 0.000010 seconds
# Loop 1778/2000 took: 0.000010 seconds
# Loop 1779/2000 took: 0.000010 seconds
# Loop 1780/2000 took: 0.000010 seconds
# Loop 1781/2000 took: 0.000010 seconds
# Loop 1782/2000 took: 0.000011 seconds
# Loop 1783/2000 took: 0.000010 seconds
# Loop 1784/2000 took: 0.000010 seconds
# Loop 1785/2000 took: 0.000009 seconds
# Loop 1786/2000 took: 0.000010 seconds
# Loop 1787/2000 took: 0.000010 seconds
# Loop 1788/2000 took: 0.000010 seconds
# Loop 1789/2000 took: 0.000010 seconds
# Loop 1790/2000 took: 0.000010 seconds
# Loop 1791/2000 took: 0.000010 seconds
# Loop 1792/2000 took: 0.000010 seconds
# Loop 1793/2000 took: 0.000011 seconds
# Loop 1794/2000 took: 0.000010 seconds
# Loop 1795/2000 took: 0.000010 seconds
# Loop 1796/2000 took: 0.000010 seconds
# Loop 1797/2000 took: 0.000010 seconds
# Loop 1798/2000 took: 0.000010 seconds
# Loop 1799/2000 took: 0.000010 seconds
# Loop 1800/2000 took: 0.000010 seconds
# Loop 1801/2000 took: 0.000010 seconds
# Loop 1802/2000 took: 0.000010 seconds
# Loop 1803/2000 took: 0.000012 seconds
# Loop 1804/2000 took: 0.000014 seconds
# Loop 1805/2000 took: 0.000010 seconds
# Loop 1806/2000 took: 0.000010 seconds
# Loop 1807/2000 took: 0.000010 seconds
# Loop 1808/2000 took: 0.000010 seconds
# Loop 1809/2000 took: 0.000010 seconds
# Loop 1810/2000 took: 0.000010 seconds
# Loop 1811/2000 took: 0.000010 seconds
# Loop 1812/2000 took: 0.000010 seconds
# Loop 1813/2000 took: 0.000011 seconds
# Loop 1814/2000 took: 0.000010 seconds
# Loop 1815/2000 took: 0.000010 seconds
# Loop 1816/2000 took: 0.000010 seconds
# Loop 1817/2000 took: 0.000010 seconds
# Loop 1818/2000 took: 0.000009 seconds
# Loop 1819/2000 took: 0.000010 seconds
# Loop 1820/2000 took: 0.000010 seconds
# Loop 1821/2000 took: 0.000010 seconds
# Loop 1822/2000 took: 0.000010 seconds
# Loop 1823/2000 took: 0.000011 seconds
# Loop 1824/2000 took: 0.000010 seconds
# Loop 1825/2000 took: 0.000010 seconds
# Loop 1826/2000 took: 0.000010 seconds
# Loop 1827/2000 took: 0.000010 seconds
# Loop 1828/2000 took: 0.000010 seconds
# Loop 1829/2000 took: 0.000010 seconds
# Loop 1830/2000 took: 0.000010 seconds
# Loop 1831/2000 took: 0.000010 seconds
# Loop 1832/2000 took: 0.000010 seconds
# Loop 1833/2000 took: 0.000011 seconds
# Loop 1834/2000 took: 0.000010 seconds
# Loop 1835/2000 took: 0.000010 seconds
# Loop 1836/2000 took: 0.000010 seconds
# Loop 1837/2000 took: 0.000010 seconds
# Loop 1838/2000 took: 0.000010 seconds
# Loop 1839/2000 took: 0.000010 seconds
# Loop 1840/2000 took: 0.000010 seconds
# Loop 1841/2000 took: 0.000010 seconds
# Loop 1842/2000 took: 0.000010 seconds
# Loop 1843/2000 took: 0.000010 seconds
# Loop 1844/2000 took: 0.000011 seconds
# Loop 1845/2000 took: 0.000010 seconds
# Loop 1846/2000 took: 0.000010 seconds
# Loop 1847/2000 took: 0.000010 seconds
# Loop 1848/2000 took: 0.000010 seconds
# Loop 1849/2000 took: 0.000009 seconds
# Loop 1850/2000 took: 0.000010 seconds
# Loop 1851/2000 took: 0.000010 seconds
# Loop 1852/2000 took: 0.000022 seconds
# Loop 1853/2000 took: 0.000012 seconds
# Loop 1854/2000 took: 0.000014 seconds
# Loop 1855/2000 took: 0.000011 seconds
# Loop 1856/2000 took: 0.000010 seconds
# Loop 1857/2000 took: 0.000010 seconds
# Loop 1858/2000 took: 0.000011 seconds
# Loop 1859/2000 took: 0.000010 seconds
# Loop 1860/2000 took: 0.000010 seconds
# Loop 1861/2000 took: 0.000010 seconds
# Loop 1862/2000 took: 0.000010 seconds
# Loop 1863/2000 took: 0.000010 seconds
# Loop 1864/2000 took: 0.000014 seconds
# Loop 1865/2000 took: 0.000011 seconds
# Loop 1866/2000 took: 0.000010 seconds
# Loop 1867/2000 took: 0.000010 seconds
# Loop 1868/2000 took: 0.000010 seconds
# Loop 1869/2000 took: 0.000010 seconds
# Loop 1870/2000 took: 0.000010 seconds
# Loop 1871/2000 took: 0.000010 seconds
# Loop 1872/2000 took: 0.000010 seconds
# Loop 1873/2000 took: 0.000010 seconds
# Loop 1874/2000 took: 0.000011 seconds
# Loop 1875/2000 took: 0.000010 seconds
# Loop 1876/2000 took: 0.000010 seconds
# Loop 1877/2000 took: 0.000010 seconds
# Loop 1878/2000 took: 0.000010 seconds
# Loop 1879/2000 took: 0.000010 seconds
# Loop 1880/2000 took: 0.000010 seconds
# Loop 1881/2000 took: 0.000010 seconds
# Loop 1882/2000 took: 0.000010 seconds
# Loop 1883/2000 took: 0.000010 seconds
# Loop 1884/2000 took: 0.000010 seconds
# Loop 1885/2000 took: 0.000011 seconds
# Loop 1886/2000 took: 0.000010 seconds
# Loop 1887/2000 took: 0.000010 seconds
# Loop 1888/2000 took: 0.000010 seconds
# Loop 1889/2000 took: 0.000010 seconds
# Loop 1890/2000 took: 0.000010 seconds
# Loop 1891/2000 took: 0.000010 seconds
# Loop 1892/2000 took: 0.000010 seconds
# Loop 1893/2000 took: 0.000010 seconds
# Loop 1894/2000 took: 0.000010 seconds
# Loop 1895/2000 took: 0.000011 seconds
# Loop 1896/2000 took: 0.000011 seconds
# Loop 1897/2000 took: 0.000010 seconds
# Loop 1898/2000 took: 0.000010 seconds
# Loop 1899/2000 took: 0.000010 seconds
# Loop 1900/2000 took: 0.000010 seconds
# Loop 1901/2000 took: 0.000010 seconds
# Loop 1902/2000 took: 0.000010 seconds
# Loop 1903/2000 took: 0.000010 seconds
# Loop 1904/2000 took: 0.000010 seconds
# Loop 1905/2000 took: 0.000011 seconds
# Loop 1906/2000 took: 0.000010 seconds
# Loop 1907/2000 took: 0.000010 seconds
# Loop 1908/2000 took: 0.000010 seconds
# Loop 1909/2000 took: 0.000010 seconds
# Loop 1910/2000 took: 0.000010 seconds
# Loop 1911/2000 took: 0.000010 seconds
# Loop 1912/2000 took: 0.000010 seconds
# Loop 1913/2000 took: 0.000010 seconds
# Loop 1914/2000 took: 0.000010 seconds
# Loop 1915/2000 took: 0.000011 seconds
# Loop 1916/2000 took: 0.000010 seconds
# Loop 1917/2000 took: 0.000010 seconds
# Loop 1918/2000 took: 0.000010 seconds
# Loop 1919/2000 took: 0.000010 seconds
# Loop 1920/2000 took: 0.000010 seconds
# Loop 1921/2000 took: 0.000010 seconds
# Loop 1922/2000 took: 0.000010 seconds
# Loop 1923/2000 took: 0.000010 seconds
# Loop 1924/2000 took: 0.000010 seconds
# Loop 1925/2000 took: 0.000010 seconds
# Loop 1926/2000 took: 0.000011 seconds
# Loop 1927/2000 took: 0.000010 seconds
# Loop 1928/2000 took: 0.000010 seconds
# Loop 1929/2000 took: 0.000010 seconds
# Loop 1930/2000 took: 0.000010 seconds
# Loop 1931/2000 took: 0.000010 seconds
# Loop 1932/2000 took: 0.000010 seconds
# Loop 1933/2000 took: 0.000010 seconds
# Loop 1934/2000 took: 0.000010 seconds
# Loop 1935/2000 took: 0.000010 seconds
# Loop 1936/2000 took: 0.000011 seconds
# Loop 1937/2000 took: 0.000010 seconds
# Loop 1938/2000 took: 0.000010 seconds
# Loop 1939/2000 took: 0.000010 seconds
# Loop 1940/2000 took: 0.000010 seconds
# Loop 1941/2000 took: 0.000010 seconds
# Loop 1942/2000 took: 0.000010 seconds
# Loop 1943/2000 took: 0.000010 seconds
# Loop 1944/2000 took: 0.000010 seconds
# Loop 1945/2000 took: 0.000010 seconds
# Loop 1946/2000 took: 0.000011 seconds
# Loop 1947/2000 took: 0.000010 seconds
# Loop 1948/2000 took: 0.000010 seconds
# Loop 1949/2000 took: 0.000010 seconds
# Loop 1950/2000 took: 0.000010 seconds
# Loop 1951/2000 took: 0.000010 seconds
# Loop 1952/2000 took: 0.000010 seconds
# Loop 1953/2000 took: 0.000010 seconds
# Loop 1954/2000 took: 0.000010 seconds
# Loop 1955/2000 took: 0.000010 seconds
# Loop 1956/2000 took: 0.000012 seconds
# Loop 1957/2000 took: 0.000010 seconds
# Loop 1958/2000 took: 0.000010 seconds
# Loop 1959/2000 took: 0.000010 seconds
# Loop 1960/2000 took: 0.000010 seconds
# Loop 1961/2000 took: 0.000010 seconds
# Loop 1962/2000 took: 0.000010 seconds
# Loop 1963/2000 took: 0.000010 seconds
# Loop 1964/2000 took: 0.000010 seconds
# Loop 1965/2000 took: 0.000010 seconds
# Loop 1966/2000 took: 0.000010 seconds
# Loop 1967/2000 took: 0.000012 seconds
# Loop 1968/2000 took: 0.000010 seconds
# Loop 1969/2000 took: 0.000010 seconds
# Loop 1970/2000 took: 0.000010 seconds
# Loop 1971/2000 took: 0.000010 seconds
# Loop 1972/2000 took: 0.000010 seconds
# Loop 1973/2000 took: 0.000010 seconds
# Loop 1974/2000 took: 0.000010 seconds
# Loop 1975/2000 took: 0.000010 seconds
# Loop 1976/2000 took: 0.000010 seconds
# Loop 1977/2000 took: 0.000012 seconds
# Loop 1978/2000 took: 0.000010 seconds
# Loop 1979/2000 took: 0.000010 seconds
# Loop 1980/2000 took: 0.000010 seconds
# Loop 1981/2000 took: 0.000010 seconds
# Loop 1982/2000 took: 0.000010 seconds
# Loop 1983/2000 took: 0.000010 seconds
# Loop 1984/2000 took: 0.000010 seconds
# Loop 1985/2000 took: 0.000010 seconds
# Loop 1986/2000 took: 0.000010 seconds
# Loop 1987/2000 took: 0.000011 seconds
# Loop 1988/2000 took: 0.000010 seconds
# Loop 1989/2000 took: 0.000010 seconds
# Loop 1990/2000 took: 0.000010 seconds
# Loop 1991/2000 took: 0.000010 seconds
# Loop 1992/2000 took: 0.000010 seconds
# Loop 1993/2000 took: 0.000010 seconds
# Loop 1994/2000 took: 0.000010 seconds
# Loop 1995/2000 took: 0.000010 seconds
# Loop 1996/2000 took: 0.000010 seconds
# Loop 1997/2000 took: 0.000014 seconds
# Loop 1998/2000 took: 0.000010 seconds
# Loop 1999/2000 took: 0.000010 seconds
# Loop 2000/2000 took: 0.000010 seconds
# Total time for 2000 loops: 0.114782 seconds

# %% [markdown]
# I am not sure why problem 5 is not working. I think a straightforward reuse of the code in (2), specific to the bootstrap dataset as I have done below, should work fine. I think it is possible that the way I constructed the bootstrap array as a 2000x3 space with resample indices for the first column, is causing an issue. But then again, I just have to access the 2nd and third columns to get the measurement and uncertainty values and I did that below. Unfortunately, I had to submit this as it is without resolving the bug.

# %%
#PROBLEM 5

#Repeating (2) for the bootstrap set

def squared_loss_bootstrap(y, y_fit, dy):
    # minimizing the sum of the residuals will result in our best-fit mean
    return np.sum(((y - y_fit) / dy) ** 2, -1) # -1 is a sum over a specific axis for the 1D array in question (for multi-dimensional arrays, we could specify an axis to sum over)

f_squared_bootstrap = lambda beta: squared_loss_bootstrap(bootstrap_resamplings[:,1], beta_bootstrap, bootstrap_resamplings[:,2]) # lambda is an option that allows us to pre-load guesses into our callable function so we do not have to change the function or function call itself when we want to adjust our initial guess beta
beta_bootstrap = 4 # guess for fitting algorithm to start with

# adjusting our initial guess for the mean by iteratively going thorugh selections of beta, until the residual sum is minimized
best_fit_mean_bootstrap = optimize.fmin(f_squared_bootstrap,beta_bootstrap)
print("The mean from our fitting algorithm, from the bootstrap set, is: %.4f" % best_fit_mean_bootstrap)



# the second method for extracting the mean of our data is by directly maximizing the Likelihood function

xgrid_bootstrap = np.linspace(3,5,1000) # array space for possible mean values
L_single_bootstrap = np.ones((bootstrap_resamplings.shape[0],1000)) # allocating array space for individual measurement likelihoods
for i in range(len(bootstrap_resamplings)): # continuing loop through each paired data point
    L_single_bootstrap[i] = norm.pdf(xgrid_bootstrap,loc=bootstrap_resamplings[i,1],scale=bootstrap_resamplings[i,2]) # inidividual measurement likelihoods stored

L_bootstrap = np.prod(L_single_bootstrap,axis=0) # Likelihood for dataset as a whole

sorted_indices_bootstrap = np.argsort(L_bootstrap)[-1] # argsort rearranges array in ascending order, [-1] chooses the last value in array and that is the maximum likelihood value
print("The MLE for the mean from the bootstrap set is: %.4f" % xgrid_bootstrap[sorted_indices_bootstrap])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/miniconda3/envs/astr8070/lib/python3.13/site-packages/scipy/optimize/_optimize.py:532, in _wrap_scalar_function_maxfun_validation.<locals>.function_wrapper(x, *wrapper_args)
#     531 try:
# --> 532     fx = np.asarray(fx).item()
#     533 except (TypeError, ValueError) as e:
#
# ValueError: can only convert an array of size 1 to a Python scalar
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 13
#      10 beta_bootstrap = 4 # guess for fitting algorithm to start with
#      12 # adjusting our initial guess for the mean by iteratively going thorugh selections of beta, until the residual sum is minimized
# ---> 13 best_fit_mean_bootstrap = optimize.fmin(f_squared_bootstrap,beta_bootstrap)
#      14 print("The mean from our fitting algorithm, from the bootstrap set, is: %.4f" % best_fit_mean_bootstrap)
#      18 # the second method for extracting the mean of our data is by directly maximizing the Likelihood function
#
# File ~/miniconda3/envs/astr8070/lib/python3.13/site-packages/scipy/optimize/_optimize.py:653, in fmin(func, x0, args, xtol, ftol, maxiter, maxfun, full_output, disp, retall, callback, initial_simplex)
#     644 opts = {'xatol': xtol,
#     645         'fatol': ftol,
#     646         'maxiter': maxiter,
#    (...)
#     649         'return_all': retall,
#     650         'initial_simplex': initial_simplex}
#     652 callback = _wrap_callback(callback)
# --> 653 res = _minimize_neldermead(func, x0, args, callback=callback, **opts)
#     654 if full_output:
#     655     retlist = res['x'], res['fun'], res['nit'], res['nfev'], res['status']
#
# File ~/miniconda3/envs/astr8070/lib/python3.13/site-packages/scipy/optimize/_optimize.py:817, in _minimize_neldermead(func, x0, args, callback, maxiter, maxfev, disp, return_all, initial_simplex, xatol, fatol, adaptive, bounds, **unknown_options)
#     815 try:
#     816     for k in range(N + 1):
# --> 817         fsim[k] = func(sim[k])
#     818 except _MaxFuncCallError:
#     819     pass
#
# File ~/miniconda3/envs/astr8070/lib/python3.13/site-packages/scipy/optimize/_optimize.py:534, in _wrap_scalar_function_maxfun_validation.<locals>.function_wrapper(x, *wrapper_args)
#     532         fx = np.asarray(fx).item()
#     533     except (TypeError, ValueError) as e:
# --> 534         raise ValueError("The user-provided objective function "
#     535                          "must return a scalar value.") from e
#     536 return fx
#
# ValueError: The user-provided objective function must return a scalar value.
